# %%
import numpy as np #para manejo de vectores
import matplotlib.pyplot as plt #para gráficas
import math # para operaciones matemáticas
import random #para números aleatorios
# %matplotlib notebook

# %% [markdown]
# Valores iniciales:
# Los vectores son de dimensión $dim = 10$
#
# El dominio de cada coordenada es $[xmin,xmax] = [-10,10]$
#
# La población inicial es de 100 individuos
#
# Se generan vectores de manera aleatoria uniforme, considerando el artículo de Ono acerca de UNDX, el valor de la varianza para el eje principal es
# $$\sigma^2_\xi=\frac{1}{4}$$
# y para el espacio ortogonal:
# $$\sigma^2_\eta=\frac{2}{3(n-1)} =  \frac{2}{9}$$
#
# pues $n=dim =10$.
#
# Este es un algoritmo genético que sigue la propuesta de Ono:
# * Generar de manera aleatoria vectores de dimensión 10
# * Elegir dos individuos de manera aleatoria sin reemplazo
# * Generar decendencia aplicando UNDX a los individuos elegidos, se repite este proceso $n_c$ veces para crear $2\times n_c$ decendientes
# * Sobreviven dos individuos de la familia que contiene a los padres y su decendencia; uno es el mejor individuo y el otro es elegido mediante ruleta. Los elementos reemplazan a los padres en la población
# * Se repiten los pasos anteriores hasta algún criterio de paro

# %%
dim = 10
xmin = -5.12
xmax = 5.12

vareta =0.074
varxi = 0.25


pobsize = 300
n_c = 120
pob_mut= 0.03 
maxiter = 2500

# %%
########### Norma de un vector para ahorrar notación #################
def norma(v):
    return np.linalg.norm(v)

# %%
############ Generar vectores n dimensionales de manera aleatoria uniforme ##############
def create_pob(pobsize):
    pob = []
    for i in range(pobsize):
        vector = []
        for j in range(dim):
            x = random.uniform(-5.12,5.12)
            vector.append(x)            
        vector = np.array(vector)
        pob.append(vector)
    return pob

# %%
########## Función fitness a optimizar, hallar mínimo en este caso ###########
def aptitud(x):    
    suma = np.sum(x**2 - 10 * np.cos(2 * np.pi * x))
    resultado = 10*dim + suma
    return resultado

# %%
##############################################################
# Calcula el complemento ortogonal de un vector              #
# El resultado es una base de n-1 elementos de dimension n   #
##############################################################
def orthogonal_vectors(base_vector, num_vectors = dim -1):
    vectors = []
    while len(vectors) < num_vectors:
        vec = np.random.rand(dim)
        for v in vectors + [base_vector]:
            epsilon = 1e-8  #np batalla para dividir entre números pequeños
            vec -= np.dot(vec, v) / (np.dot(v, v) + epsilon) * v #sumo un número pequeño para evitar errores
        if norma(vec) > 1e-5:  
            vectors.append(vec / norma(vec))  
    return np.array(vectors)

# %%
##############################################
# Genera el elemento del espacio ortogonal   #
# usando la varianza teorica                 #
##############################################

def gen_corth(base):
    vect = 0
    for i in base:
        etai = np.random.normal(0,np.sqrt(vareta))
        vect += etai * i
    return vect

# %%
def mut_uniform(childs, prob_mut):
    for child in childs:
        for i in range(len(child)):
            if np.random.rand() < prob_mut:
                child[i] = np.random.uniform(xmin,xmax)
    return childs

# %%
###############################################################
# Segun ono sobrevive el mejor y el que gane                  #
# ruleta, la ruleta esta basada en la aptitud                 #
# como se intenta minimizar tomo el inverso multiplicativo    #
# para que la menor aptitud tenga mayor probabilidad          #
# de ser elegida                                              #
###############################################################
def survival_selection(family):
    best = min(family, key=lambda individual: aptitud(individual))
    weights = [1.0 / (aptitud(ind) + 1e-6) for ind in family]  
    roulette_selection = random.choices(family, weights=weights, k=1)[0]
    return best, roulette_selection

# %%
#################################################################
# Operador undx, recibe a la población y arroja a la población  #
# con el reemplazo hecho por la ruleta  y el mejor              #
#################################################################
def undx(pob, n_c,pob_mut):
    epsilon = 1e-8
    padres = random.sample(pob, 3)
    x1, x2, x3 = padres
    xp = 0.5 * (x2 + x1)
    d = x2 - x1
    offspring = []

    for _ in range(n_c):
        x31 = x3 - x1
        x21 = x2 - x1
        D = math.sqrt(norma(x31)**2 * (1 - (np.dot(x31, x21) / (norma(x31) * norma(x21) + epsilon))**2))
        orth_vects = orthogonal_vectors(d, num_vectors=dim-1)
        comp_orth = gen_corth(orth_vects)
        xi = np.random.normal(0, np.sqrt(varxi))
        x_c = xp + xi * d + comp_orth
        x_c2 = xp - xi * d - comp_orth
        offspring.extend([x_c, x_c2])
         
    offspring = mut_uniform(offspring,pob_mut)

    family = [x1, x2, x3] + offspring
    
    best, roulette = survival_selection(family)    

    for idx in range(len(pob)):
        if np.array_equal(pob[idx], x1):
            pob[idx] = best
            break

    for idx in range(len(pob)):
        if np.array_equal(pob[idx], x2):
            pob[idx] = roulette
            break

    sorted_pob = sorted(pob, key=lambda individual: aptitud(individual))

    return sorted_pob

# %%
inpob = create_pob(pobsize)
x = np.array([arr[0] for arr in inpob])
y = np.array([arr[1] for arr in inpob])
z = np.array([arr[2] for arr in inpob])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


scatter = ax.scatter(x, y,z,  alpha =0.8)

ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_zlabel('Z Coordinate')

plt.show()

# %%
resultados= []
for i in range(maxiter):
    inpob = undx(inpob, n_c,pob_mut)
    print(f"generación {i+1} tiene como mejor aptitud {aptitud(inpob[0])}")
    resultados.append(aptitud(inpob[0]))
# Out:
# generación 1 tiene como mejor aptitud 73.54050456293187
# generación 2 tiene como mejor aptitud 73.54050456293187
# generación 3 tiene como mejor aptitud 66.5755917129258
# generación 4 tiene como mejor aptitud 66.5755917129258
# generación 5 tiene como mejor aptitud 66.5755917129258
# generación 6 tiene como mejor aptitud 66.5755917129258
# generación 7 tiene como mejor aptitud 66.5755917129258
# generación 8 tiene como mejor aptitud 66.5755917129258
# generación 9 tiene como mejor aptitud 66.5755917129258
# generación 10 tiene como mejor aptitud 66.5755917129258
# generación 11 tiene como mejor aptitud 66.5755917129258
# generación 12 tiene como mejor aptitud 66.5755917129258
# generación 13 tiene como mejor aptitud 59.6478264159139
# generación 14 tiene como mejor aptitud 59.6478264159139
# generación 15 tiene como mejor aptitud 59.6478264159139
# generación 16 tiene como mejor aptitud 59.6478264159139
# generación 17 tiene como mejor aptitud 59.6478264159139
# generación 18 tiene como mejor aptitud 59.6478264159139
# generación 19 tiene como mejor aptitud 59.6478264159139
# generación 20 tiene como mejor aptitud 59.6478264159139
# generación 21 tiene como mejor aptitud 59.6478264159139
# generación 22 tiene como mejor aptitud 59.6478264159139
# generación 23 tiene como mejor aptitud 59.6478264159139
# generación 24 tiene como mejor aptitud 59.6478264159139
# generación 25 tiene como mejor aptitud 59.6478264159139
# generación 26 tiene como mejor aptitud 59.6478264159139
# generación 27 tiene como mejor aptitud 59.6478264159139
# generación 28 tiene como mejor aptitud 59.6478264159139
# generación 29 tiene como mejor aptitud 59.6478264159139
# generación 30 tiene como mejor aptitud 59.6478264159139
# generación 31 tiene como mejor aptitud 59.6478264159139
# generación 32 tiene como mejor aptitud 59.6478264159139
# generación 33 tiene como mejor aptitud 59.6478264159139
# generación 34 tiene como mejor aptitud 59.6478264159139
# generación 35 tiene como mejor aptitud 59.6478264159139
# generación 36 tiene como mejor aptitud 59.6478264159139
# generación 37 tiene como mejor aptitud 59.6478264159139
# generación 38 tiene como mejor aptitud 59.6478264159139
# generación 39 tiene como mejor aptitud 59.6478264159139
# generación 40 tiene como mejor aptitud 59.6478264159139
# generación 41 tiene como mejor aptitud 59.6478264159139
# generación 42 tiene como mejor aptitud 59.6478264159139
# generación 43 tiene como mejor aptitud 59.6478264159139
# generación 44 tiene como mejor aptitud 59.6478264159139
# generación 45 tiene como mejor aptitud 59.6478264159139
# generación 46 tiene como mejor aptitud 50.921426895465046
# generación 47 tiene como mejor aptitud 50.921426895465046
# generación 48 tiene como mejor aptitud 50.921426895465046
# generación 49 tiene como mejor aptitud 50.921426895465046
# generación 50 tiene como mejor aptitud 50.921426895465046
# generación 51 tiene como mejor aptitud 50.921426895465046
# generación 52 tiene como mejor aptitud 50.921426895465046
# generación 53 tiene como mejor aptitud 50.921426895465046
# generación 54 tiene como mejor aptitud 50.921426895465046
# generación 55 tiene como mejor aptitud 50.921426895465046
# generación 56 tiene como mejor aptitud 50.921426895465046
# generación 57 tiene como mejor aptitud 50.921426895465046
# generación 58 tiene como mejor aptitud 50.921426895465046
# generación 59 tiene como mejor aptitud 50.921426895465046
# generación 60 tiene como mejor aptitud 50.921426895465046
# generación 61 tiene como mejor aptitud 50.921426895465046
# generación 62 tiene como mejor aptitud 50.921426895465046
# generación 63 tiene como mejor aptitud 50.921426895465046
# generación 64 tiene como mejor aptitud 50.921426895465046
# generación 65 tiene como mejor aptitud 50.921426895465046
# generación 66 tiene como mejor aptitud 50.921426895465046
# generación 67 tiene como mejor aptitud 50.921426895465046
# generación 68 tiene como mejor aptitud 50.921426895465046
# generación 69 tiene como mejor aptitud 50.921426895465046
# generación 70 tiene como mejor aptitud 50.921426895465046
# generación 71 tiene como mejor aptitud 50.921426895465046
# generación 72 tiene como mejor aptitud 50.921426895465046
# generación 73 tiene como mejor aptitud 50.921426895465046
# generación 74 tiene como mejor aptitud 50.921426895465046
# generación 75 tiene como mejor aptitud 50.921426895465046
# generación 76 tiene como mejor aptitud 50.921426895465046
# generación 77 tiene como mejor aptitud 50.921426895465046
# generación 78 tiene como mejor aptitud 50.921426895465046
# generación 79 tiene como mejor aptitud 50.921426895465046
# generación 80 tiene como mejor aptitud 50.921426895465046
# generación 81 tiene como mejor aptitud 50.921426895465046
# generación 82 tiene como mejor aptitud 50.921426895465046
# generación 83 tiene como mejor aptitud 50.921426895465046
# generación 84 tiene como mejor aptitud 50.921426895465046
# generación 85 tiene como mejor aptitud 50.921426895465046
# generación 86 tiene como mejor aptitud 50.921426895465046
# generación 87 tiene como mejor aptitud 50.921426895465046
# generación 88 tiene como mejor aptitud 50.921426895465046
# generación 89 tiene como mejor aptitud 50.921426895465046
# generación 90 tiene como mejor aptitud 50.921426895465046
# generación 91 tiene como mejor aptitud 50.921426895465046
# generación 92 tiene como mejor aptitud 50.81305026090887
# generación 93 tiene como mejor aptitud 50.81305026090887
# generación 94 tiene como mejor aptitud 50.81305026090887
# generación 95 tiene como mejor aptitud 50.81305026090887
# generación 96 tiene como mejor aptitud 50.81305026090887
# generación 97 tiene como mejor aptitud 50.81305026090887
# generación 98 tiene como mejor aptitud 50.81305026090887
# generación 99 tiene como mejor aptitud 50.81305026090887
# generación 100 tiene como mejor aptitud 50.81305026090887
# generación 101 tiene como mejor aptitud 50.81305026090887
# generación 102 tiene como mejor aptitud 50.81305026090887
# generación 103 tiene como mejor aptitud 50.81305026090887
# generación 104 tiene como mejor aptitud 50.81305026090887
# generación 105 tiene como mejor aptitud 45.33424300972978
# generación 106 tiene como mejor aptitud 45.33424300972978
# generación 107 tiene como mejor aptitud 45.33424300972978
# generación 108 tiene como mejor aptitud 45.33424300972978
# generación 109 tiene como mejor aptitud 45.33424300972978
# generación 110 tiene como mejor aptitud 45.33424300972978
# generación 111 tiene como mejor aptitud 45.33424300972978
# generación 112 tiene como mejor aptitud 45.33424300972978
# generación 113 tiene como mejor aptitud 45.33424300972978
# generación 114 tiene como mejor aptitud 45.33424300972978
# generación 115 tiene como mejor aptitud 45.33424300972978
# generación 116 tiene como mejor aptitud 45.33424300972978
# generación 117 tiene como mejor aptitud 45.33424300972978
# generación 118 tiene como mejor aptitud 45.33424300972978
# generación 119 tiene como mejor aptitud 45.33424300972978
# generación 120 tiene como mejor aptitud 45.33424300972978
# generación 121 tiene como mejor aptitud 45.33424300972978
# generación 122 tiene como mejor aptitud 45.33424300972978
# generación 123 tiene como mejor aptitud 45.33424300972978
# generación 124 tiene como mejor aptitud 45.33424300972978
# generación 125 tiene como mejor aptitud 45.33424300972978
# generación 126 tiene como mejor aptitud 45.33424300972978
# generación 127 tiene como mejor aptitud 45.33424300972978
# generación 128 tiene como mejor aptitud 45.33424300972978
# generación 129 tiene como mejor aptitud 42.51790416877557
# generación 130 tiene como mejor aptitud 42.51790416877557
# generación 131 tiene como mejor aptitud 42.51790416877557
# generación 132 tiene como mejor aptitud 42.51790416877557
# generación 133 tiene como mejor aptitud 42.51790416877557
# generación 134 tiene como mejor aptitud 42.51790416877557
# generación 135 tiene como mejor aptitud 42.51790416877557
# generación 136 tiene como mejor aptitud 42.51790416877557
# generación 137 tiene como mejor aptitud 42.51790416877557
# generación 138 tiene como mejor aptitud 42.51790416877557
# generación 139 tiene como mejor aptitud 42.51790416877557
# generación 140 tiene como mejor aptitud 42.51790416877557
# generación 141 tiene como mejor aptitud 42.51790416877557
# generación 142 tiene como mejor aptitud 42.51790416877557
# generación 143 tiene como mejor aptitud 42.51790416877557
# generación 144 tiene como mejor aptitud 42.51790416877557
# generación 145 tiene como mejor aptitud 42.51790416877557
# generación 146 tiene como mejor aptitud 42.51790416877557
# generación 147 tiene como mejor aptitud 42.51790416877557
# generación 148 tiene como mejor aptitud 42.51790416877557
# generación 149 tiene como mejor aptitud 42.51790416877557
# generación 150 tiene como mejor aptitud 42.51790416877557
# generación 151 tiene como mejor aptitud 42.51790416877557
# generación 152 tiene como mejor aptitud 42.51790416877557
# generación 153 tiene como mejor aptitud 42.51790416877557
# generación 154 tiene como mejor aptitud 42.51790416877557
# generación 155 tiene como mejor aptitud 42.51790416877557
# generación 156 tiene como mejor aptitud 42.51790416877557
# generación 157 tiene como mejor aptitud 42.51790416877557
# generación 158 tiene como mejor aptitud 42.51790416877557
# generación 159 tiene como mejor aptitud 42.51790416877557
# generación 160 tiene como mejor aptitud 42.51790416877557
# generación 161 tiene como mejor aptitud 42.51790416877557
# generación 162 tiene como mejor aptitud 42.51790416877557
# generación 163 tiene como mejor aptitud 42.51790416877557
# generación 164 tiene como mejor aptitud 42.51790416877557
# generación 165 tiene como mejor aptitud 42.51790416877557
# generación 166 tiene como mejor aptitud 42.51790416877557
# generación 167 tiene como mejor aptitud 42.51790416877557
# generación 168 tiene como mejor aptitud 42.51790416877557
# generación 169 tiene como mejor aptitud 42.51790416877557
# generación 170 tiene como mejor aptitud 42.51790416877557
# generación 171 tiene como mejor aptitud 42.51790416877557
# generación 172 tiene como mejor aptitud 42.51790416877557
# generación 173 tiene como mejor aptitud 42.51790416877557
# generación 174 tiene como mejor aptitud 42.51790416877557
# generación 175 tiene como mejor aptitud 42.51790416877557
# generación 176 tiene como mejor aptitud 42.51790416877557
# generación 177 tiene como mejor aptitud 42.51790416877557
# generación 178 tiene como mejor aptitud 42.51790416877557
# generación 179 tiene como mejor aptitud 42.51790416877557
# generación 180 tiene como mejor aptitud 42.51790416877557
# generación 181 tiene como mejor aptitud 42.51790416877557
# generación 182 tiene como mejor aptitud 42.51790416877557
# generación 183 tiene como mejor aptitud 42.51790416877557
# generación 184 tiene como mejor aptitud 42.51790416877557
# generación 185 tiene como mejor aptitud 42.51790416877557
# generación 186 tiene como mejor aptitud 42.51790416877557
# generación 187 tiene como mejor aptitud 42.51790416877557
# generación 188 tiene como mejor aptitud 42.51790416877557
# generación 189 tiene como mejor aptitud 42.51790416877557
# generación 190 tiene como mejor aptitud 42.51790416877557
# generación 191 tiene como mejor aptitud 42.51790416877557
# generación 192 tiene como mejor aptitud 42.51790416877557
# generación 193 tiene como mejor aptitud 42.51790416877557
# generación 194 tiene como mejor aptitud 42.51790416877557
# generación 195 tiene como mejor aptitud 42.51790416877557
# generación 196 tiene como mejor aptitud 42.51790416877557
# generación 197 tiene como mejor aptitud 42.51790416877557
# generación 198 tiene como mejor aptitud 42.51790416877557
# generación 199 tiene como mejor aptitud 42.51790416877557
# generación 200 tiene como mejor aptitud 42.51790416877557
# generación 201 tiene como mejor aptitud 42.51790416877557
# generación 202 tiene como mejor aptitud 42.51790416877557
# generación 203 tiene como mejor aptitud 42.51790416877557
# generación 204 tiene como mejor aptitud 42.51790416877557
# generación 205 tiene como mejor aptitud 42.51790416877557
# generación 206 tiene como mejor aptitud 42.51790416877557
# generación 207 tiene como mejor aptitud 42.51790416877557
# generación 208 tiene como mejor aptitud 42.51790416877557
# generación 209 tiene como mejor aptitud 42.51790416877557
# generación 210 tiene como mejor aptitud 35.250631132980686
# generación 211 tiene como mejor aptitud 35.250631132980686
# generación 212 tiene como mejor aptitud 35.250631132980686
# generación 213 tiene como mejor aptitud 35.250631132980686
# generación 214 tiene como mejor aptitud 35.250631132980686
# generación 215 tiene como mejor aptitud 35.250631132980686
# generación 216 tiene como mejor aptitud 35.250631132980686
# generación 217 tiene como mejor aptitud 35.250631132980686
# generación 218 tiene como mejor aptitud 35.250631132980686
# generación 219 tiene como mejor aptitud 35.250631132980686
# generación 220 tiene como mejor aptitud 35.250631132980686
# generación 221 tiene como mejor aptitud 35.250631132980686
# generación 222 tiene como mejor aptitud 35.250631132980686
# generación 223 tiene como mejor aptitud 35.250631132980686
# generación 224 tiene como mejor aptitud 35.250631132980686
# generación 225 tiene como mejor aptitud 35.250631132980686
# generación 226 tiene como mejor aptitud 35.250631132980686
# generación 227 tiene como mejor aptitud 35.250631132980686
# generación 228 tiene como mejor aptitud 35.250631132980686
# generación 229 tiene como mejor aptitud 35.250631132980686
# generación 230 tiene como mejor aptitud 35.250631132980686
# generación 231 tiene como mejor aptitud 35.250631132980686
# generación 232 tiene como mejor aptitud 35.250631132980686
# generación 233 tiene como mejor aptitud 35.250631132980686
# generación 234 tiene como mejor aptitud 35.250631132980686
# generación 235 tiene como mejor aptitud 35.250631132980686
# generación 236 tiene como mejor aptitud 35.250631132980686
# generación 237 tiene como mejor aptitud 35.250631132980686
# generación 238 tiene como mejor aptitud 35.250631132980686
# generación 239 tiene como mejor aptitud 35.250631132980686
# generación 240 tiene como mejor aptitud 35.250631132980686
# generación 241 tiene como mejor aptitud 35.250631132980686
# generación 242 tiene como mejor aptitud 35.250631132980686
# generación 243 tiene como mejor aptitud 35.250631132980686
# generación 244 tiene como mejor aptitud 35.250631132980686
# generación 245 tiene como mejor aptitud 35.250631132980686
# generación 246 tiene como mejor aptitud 35.250631132980686
# generación 247 tiene como mejor aptitud 35.250631132980686
# generación 248 tiene como mejor aptitud 35.250631132980686
# generación 249 tiene como mejor aptitud 35.250631132980686
# generación 250 tiene como mejor aptitud 35.250631132980686
# generación 251 tiene como mejor aptitud 35.250631132980686
# generación 252 tiene como mejor aptitud 35.250631132980686
# generación 253 tiene como mejor aptitud 35.250631132980686
# generación 254 tiene como mejor aptitud 35.250631132980686
# generación 255 tiene como mejor aptitud 35.250631132980686
# generación 256 tiene como mejor aptitud 35.250631132980686
# generación 257 tiene como mejor aptitud 35.250631132980686
# generación 258 tiene como mejor aptitud 35.250631132980686
# generación 259 tiene como mejor aptitud 35.250631132980686
# generación 260 tiene como mejor aptitud 35.250631132980686
# generación 261 tiene como mejor aptitud 35.250631132980686
# generación 262 tiene como mejor aptitud 35.250631132980686
# generación 263 tiene como mejor aptitud 35.250631132980686
# generación 264 tiene como mejor aptitud 35.250631132980686
# generación 265 tiene como mejor aptitud 35.250631132980686
# generación 266 tiene como mejor aptitud 35.250631132980686
# generación 267 tiene como mejor aptitud 35.250631132980686
# generación 268 tiene como mejor aptitud 35.250631132980686
# generación 269 tiene como mejor aptitud 35.250631132980686
# generación 270 tiene como mejor aptitud 35.250631132980686
# generación 271 tiene como mejor aptitud 35.250631132980686
# generación 272 tiene como mejor aptitud 35.250631132980686
# generación 273 tiene como mejor aptitud 35.250631132980686
# generación 274 tiene como mejor aptitud 33.32610187845518
# generación 275 tiene como mejor aptitud 33.32610187845518
# generación 276 tiene como mejor aptitud 33.32610187845518
# generación 277 tiene como mejor aptitud 33.32610187845518
# generación 278 tiene como mejor aptitud 33.32610187845518
# generación 279 tiene como mejor aptitud 33.32610187845518
# generación 280 tiene como mejor aptitud 33.32610187845518
# generación 281 tiene como mejor aptitud 33.32610187845518
# generación 282 tiene como mejor aptitud 33.32610187845518
# generación 283 tiene como mejor aptitud 33.32610187845518
# generación 284 tiene como mejor aptitud 33.32610187845518
# generación 285 tiene como mejor aptitud 33.32610187845518
# generación 286 tiene como mejor aptitud 33.32610187845518
# generación 287 tiene como mejor aptitud 33.32610187845518
# generación 288 tiene como mejor aptitud 33.32610187845518
# generación 289 tiene como mejor aptitud 33.32610187845518
# generación 290 tiene como mejor aptitud 33.32610187845518
# generación 291 tiene como mejor aptitud 33.32610187845518
# generación 292 tiene como mejor aptitud 33.32610187845518
# generación 293 tiene como mejor aptitud 33.32610187845518
# generación 294 tiene como mejor aptitud 33.32610187845518
# generación 295 tiene como mejor aptitud 33.32610187845518
# generación 296 tiene como mejor aptitud 33.32610187845518
# generación 297 tiene como mejor aptitud 33.32610187845518
# generación 298 tiene como mejor aptitud 33.32610187845518
# generación 299 tiene como mejor aptitud 33.32610187845518
# generación 300 tiene como mejor aptitud 33.32610187845518
# generación 301 tiene como mejor aptitud 33.32610187845518
# generación 302 tiene como mejor aptitud 33.32610187845518
# generación 303 tiene como mejor aptitud 33.32610187845518
# generación 304 tiene como mejor aptitud 33.32610187845518
# generación 305 tiene como mejor aptitud 33.32610187845518
# generación 306 tiene como mejor aptitud 33.32610187845518
# generación 307 tiene como mejor aptitud 33.32610187845518
# generación 308 tiene como mejor aptitud 33.32610187845518
# generación 309 tiene como mejor aptitud 33.32610187845518
# generación 310 tiene como mejor aptitud 33.32610187845518
# generación 311 tiene como mejor aptitud 33.32610187845518
# generación 312 tiene como mejor aptitud 33.32610187845518
# generación 313 tiene como mejor aptitud 33.32610187845518
# generación 314 tiene como mejor aptitud 33.32610187845518
# generación 315 tiene como mejor aptitud 33.32610187845518
# generación 316 tiene como mejor aptitud 33.32610187845518
# generación 317 tiene como mejor aptitud 33.32610187845518
# generación 318 tiene como mejor aptitud 33.32610187845518
# generación 319 tiene como mejor aptitud 33.32610187845518
# generación 320 tiene como mejor aptitud 33.32610187845518
# generación 321 tiene como mejor aptitud 33.32610187845518
# generación 322 tiene como mejor aptitud 33.32610187845518
# generación 323 tiene como mejor aptitud 33.32610187845518
# generación 324 tiene como mejor aptitud 33.32610187845518
# generación 325 tiene como mejor aptitud 33.32610187845518
# generación 326 tiene como mejor aptitud 33.32610187845518
# generación 327 tiene como mejor aptitud 33.32610187845518
# generación 328 tiene como mejor aptitud 33.32610187845518
# generación 329 tiene como mejor aptitud 33.32610187845518
# generación 330 tiene como mejor aptitud 33.32610187845518
# generación 331 tiene como mejor aptitud 33.32610187845518
# generación 332 tiene como mejor aptitud 33.32610187845518
# generación 333 tiene como mejor aptitud 33.32610187845518
# generación 334 tiene como mejor aptitud 33.32610187845518
# generación 335 tiene como mejor aptitud 33.32610187845518
# generación 336 tiene como mejor aptitud 33.32610187845518
# generación 337 tiene como mejor aptitud 33.32610187845518
# generación 338 tiene como mejor aptitud 33.32610187845518
# generación 339 tiene como mejor aptitud 33.32610187845518
# generación 340 tiene como mejor aptitud 33.32610187845518
# generación 341 tiene como mejor aptitud 33.32610187845518
# generación 342 tiene como mejor aptitud 33.32610187845518
# generación 343 tiene como mejor aptitud 33.32610187845518
# generación 344 tiene como mejor aptitud 32.4207805557905
# generación 345 tiene como mejor aptitud 32.4207805557905
# generación 346 tiene como mejor aptitud 32.4207805557905
# generación 347 tiene como mejor aptitud 32.4207805557905
# generación 348 tiene como mejor aptitud 32.4207805557905
# generación 349 tiene como mejor aptitud 32.4207805557905
# generación 350 tiene como mejor aptitud 32.4207805557905
# generación 351 tiene como mejor aptitud 32.4207805557905
# generación 352 tiene como mejor aptitud 32.4207805557905
# generación 353 tiene como mejor aptitud 32.4207805557905
# generación 354 tiene como mejor aptitud 32.4207805557905
# generación 355 tiene como mejor aptitud 32.4207805557905
# generación 356 tiene como mejor aptitud 32.4207805557905
# generación 357 tiene como mejor aptitud 32.4207805557905
# generación 358 tiene como mejor aptitud 30.918975388609056
# generación 359 tiene como mejor aptitud 30.918975388609056
# generación 360 tiene como mejor aptitud 30.918975388609056
# generación 361 tiene como mejor aptitud 30.918975388609056
# generación 362 tiene como mejor aptitud 30.918975388609056
# generación 363 tiene como mejor aptitud 30.918975388609056
# generación 364 tiene como mejor aptitud 30.918975388609056
# generación 365 tiene como mejor aptitud 30.918975388609056
# generación 366 tiene como mejor aptitud 30.918975388609056
# generación 367 tiene como mejor aptitud 30.918975388609056
# generación 368 tiene como mejor aptitud 30.918975388609056
# generación 369 tiene como mejor aptitud 30.918975388609056
# generación 370 tiene como mejor aptitud 30.918975388609056
# generación 371 tiene como mejor aptitud 30.918975388609056
# generación 372 tiene como mejor aptitud 30.918975388609056
# generación 373 tiene como mejor aptitud 30.918975388609056
# generación 374 tiene como mejor aptitud 30.918975388609056
# generación 375 tiene como mejor aptitud 30.918975388609056
# generación 376 tiene como mejor aptitud 30.918975388609056
# generación 377 tiene como mejor aptitud 30.918975388609056
# generación 378 tiene como mejor aptitud 30.918975388609056
# generación 379 tiene como mejor aptitud 30.918975388609056
# generación 380 tiene como mejor aptitud 30.918975388609056
# generación 381 tiene como mejor aptitud 30.918975388609056
# generación 382 tiene como mejor aptitud 30.918975388609056
# generación 383 tiene como mejor aptitud 30.918975388609056
# generación 384 tiene como mejor aptitud 24.68591865821422
# generación 385 tiene como mejor aptitud 24.68591865821422
# generación 386 tiene como mejor aptitud 24.68591865821422
# generación 387 tiene como mejor aptitud 24.68591865821422
# generación 388 tiene como mejor aptitud 24.68591865821422
# generación 389 tiene como mejor aptitud 24.68591865821422
# generación 390 tiene como mejor aptitud 24.68591865821422
# generación 391 tiene como mejor aptitud 24.68591865821422
# generación 392 tiene como mejor aptitud 24.68591865821422
# generación 393 tiene como mejor aptitud 24.68591865821422
# generación 394 tiene como mejor aptitud 24.68591865821422
# generación 395 tiene como mejor aptitud 24.68591865821422
# generación 396 tiene como mejor aptitud 24.68591865821422
# generación 397 tiene como mejor aptitud 24.68591865821422
# generación 398 tiene como mejor aptitud 24.68591865821422
# generación 399 tiene como mejor aptitud 24.68591865821422
# generación 400 tiene como mejor aptitud 24.68591865821422
# generación 401 tiene como mejor aptitud 24.68591865821422
# generación 402 tiene como mejor aptitud 24.68591865821422
# generación 403 tiene como mejor aptitud 24.68591865821422
# generación 404 tiene como mejor aptitud 24.68591865821422
# generación 405 tiene como mejor aptitud 24.68591865821422
# generación 406 tiene como mejor aptitud 24.68591865821422
# generación 407 tiene como mejor aptitud 24.68591865821422
# generación 408 tiene como mejor aptitud 24.68591865821422
# generación 409 tiene como mejor aptitud 24.68591865821422
# generación 410 tiene como mejor aptitud 24.68591865821422
# generación 411 tiene como mejor aptitud 24.68591865821422
# generación 412 tiene como mejor aptitud 24.68591865821422
# generación 413 tiene como mejor aptitud 24.68591865821422
# generación 414 tiene como mejor aptitud 24.68591865821422
# generación 415 tiene como mejor aptitud 24.68591865821422
# generación 416 tiene como mejor aptitud 24.68591865821422
# generación 417 tiene como mejor aptitud 24.68591865821422
# generación 418 tiene como mejor aptitud 24.68591865821422
# generación 419 tiene como mejor aptitud 24.68591865821422
# generación 420 tiene como mejor aptitud 24.68591865821422
# generación 421 tiene como mejor aptitud 24.68591865821422
# generación 422 tiene como mejor aptitud 24.68591865821422
# generación 423 tiene como mejor aptitud 24.68591865821422
# generación 424 tiene como mejor aptitud 24.68591865821422
# generación 425 tiene como mejor aptitud 24.68591865821422
# generación 426 tiene como mejor aptitud 24.68591865821422
# generación 427 tiene como mejor aptitud 24.68591865821422
# generación 428 tiene como mejor aptitud 24.68591865821422
# generación 429 tiene como mejor aptitud 24.68591865821422
# generación 430 tiene como mejor aptitud 24.68591865821422
# generación 431 tiene como mejor aptitud 24.68591865821422
# generación 432 tiene como mejor aptitud 24.68591865821422
# generación 433 tiene como mejor aptitud 24.68591865821422
# generación 434 tiene como mejor aptitud 24.68591865821422
# generación 435 tiene como mejor aptitud 24.68591865821422
# generación 436 tiene como mejor aptitud 24.68591865821422
# generación 437 tiene como mejor aptitud 24.68591865821422
# generación 438 tiene como mejor aptitud 24.68591865821422
# generación 439 tiene como mejor aptitud 24.68591865821422
# generación 440 tiene como mejor aptitud 24.68591865821422
# generación 441 tiene como mejor aptitud 24.68591865821422
# generación 442 tiene como mejor aptitud 24.68591865821422
# generación 443 tiene como mejor aptitud 24.68591865821422
# generación 444 tiene como mejor aptitud 24.68591865821422
# generación 445 tiene como mejor aptitud 24.68591865821422
# generación 446 tiene como mejor aptitud 24.68591865821422
# generación 447 tiene como mejor aptitud 24.68591865821422
# generación 448 tiene como mejor aptitud 24.68591865821422
# generación 449 tiene como mejor aptitud 24.68591865821422
# generación 450 tiene como mejor aptitud 24.68591865821422
# generación 451 tiene como mejor aptitud 24.68591865821422
# generación 452 tiene como mejor aptitud 24.68591865821422
# generación 453 tiene como mejor aptitud 24.68591865821422
# generación 454 tiene como mejor aptitud 24.68591865821422
# generación 455 tiene como mejor aptitud 24.68591865821422
# generación 456 tiene como mejor aptitud 24.68591865821422
# generación 457 tiene como mejor aptitud 24.68591865821422
# generación 458 tiene como mejor aptitud 24.68591865821422
# generación 459 tiene como mejor aptitud 24.68591865821422
# generación 460 tiene como mejor aptitud 24.68591865821422
# generación 461 tiene como mejor aptitud 24.68591865821422
# generación 462 tiene como mejor aptitud 24.68591865821422
# generación 463 tiene como mejor aptitud 24.68591865821422
# generación 464 tiene como mejor aptitud 24.224412500347043
# generación 465 tiene como mejor aptitud 24.224412500347043
# generación 466 tiene como mejor aptitud 24.224412500347043
# generación 467 tiene como mejor aptitud 24.224412500347043
# generación 468 tiene como mejor aptitud 24.224412500347043
# generación 469 tiene como mejor aptitud 24.224412500347043
# generación 470 tiene como mejor aptitud 24.224412500347043
# generación 471 tiene como mejor aptitud 24.224412500347043
# generación 472 tiene como mejor aptitud 24.224412500347043
# generación 473 tiene como mejor aptitud 24.224412500347043
# generación 474 tiene como mejor aptitud 24.224412500347043
# generación 475 tiene como mejor aptitud 24.224412500347043
# generación 476 tiene como mejor aptitud 24.224412500347043
# generación 477 tiene como mejor aptitud 24.224412500347043
# generación 478 tiene como mejor aptitud 24.224412500347043
# generación 479 tiene como mejor aptitud 24.224412500347043
# generación 480 tiene como mejor aptitud 24.224412500347043
# generación 481 tiene como mejor aptitud 24.224412500347043
# generación 482 tiene como mejor aptitud 24.224412500347043
# generación 483 tiene como mejor aptitud 24.224412500347043
# generación 484 tiene como mejor aptitud 24.224412500347043
# generación 485 tiene como mejor aptitud 24.224412500347043
# generación 486 tiene como mejor aptitud 24.224412500347043
# generación 487 tiene como mejor aptitud 24.224412500347043
# generación 488 tiene como mejor aptitud 24.224412500347043
# generación 489 tiene como mejor aptitud 24.224412500347043
# generación 490 tiene como mejor aptitud 24.224412500347043
# generación 491 tiene como mejor aptitud 24.224412500347043
# generación 492 tiene como mejor aptitud 24.224412500347043
# generación 493 tiene como mejor aptitud 24.224412500347043
# generación 494 tiene como mejor aptitud 24.224412500347043
# generación 495 tiene como mejor aptitud 24.224412500347043
# generación 496 tiene como mejor aptitud 24.224412500347043
# generación 497 tiene como mejor aptitud 24.224412500347043
# generación 498 tiene como mejor aptitud 24.224412500347043
# generación 499 tiene como mejor aptitud 24.224412500347043
# generación 500 tiene como mejor aptitud 24.224412500347043
# generación 501 tiene como mejor aptitud 24.224412500347043
# generación 502 tiene como mejor aptitud 24.224412500347043
# generación 503 tiene como mejor aptitud 24.224412500347043
# generación 504 tiene como mejor aptitud 24.224412500347043
# generación 505 tiene como mejor aptitud 24.224412500347043
# generación 506 tiene como mejor aptitud 24.224412500347043
# generación 507 tiene como mejor aptitud 24.224412500347043
# generación 508 tiene como mejor aptitud 24.224412500347043
# generación 509 tiene como mejor aptitud 24.224412500347043
# generación 510 tiene como mejor aptitud 24.224412500347043
# generación 511 tiene como mejor aptitud 24.224412500347043
# generación 512 tiene como mejor aptitud 24.224412500347043
# generación 513 tiene como mejor aptitud 24.224412500347043
# generación 514 tiene como mejor aptitud 24.224412500347043
# generación 515 tiene como mejor aptitud 24.224412500347043
# generación 516 tiene como mejor aptitud 24.224412500347043
# generación 517 tiene como mejor aptitud 24.224412500347043
# generación 518 tiene como mejor aptitud 24.224412500347043
# generación 519 tiene como mejor aptitud 24.224412500347043
# generación 520 tiene como mejor aptitud 24.224412500347043
# generación 521 tiene como mejor aptitud 24.224412500347043
# generación 522 tiene como mejor aptitud 24.224412500347043
# generación 523 tiene como mejor aptitud 24.224412500347043
# generación 524 tiene como mejor aptitud 24.224412500347043
# generación 525 tiene como mejor aptitud 24.224412500347043
# generación 526 tiene como mejor aptitud 24.224412500347043
# generación 527 tiene como mejor aptitud 24.224412500347043
# generación 528 tiene como mejor aptitud 24.224412500347043
# generación 529 tiene como mejor aptitud 24.224412500347043
# generación 530 tiene como mejor aptitud 24.224412500347043
# generación 531 tiene como mejor aptitud 24.224412500347043
# generación 532 tiene como mejor aptitud 24.224412500347043
# generación 533 tiene como mejor aptitud 24.224412500347043
# generación 534 tiene como mejor aptitud 24.224412500347043
# generación 535 tiene como mejor aptitud 24.224412500347043
# generación 536 tiene como mejor aptitud 24.224412500347043
# generación 537 tiene como mejor aptitud 24.224412500347043
# generación 538 tiene como mejor aptitud 24.224412500347043
# generación 539 tiene como mejor aptitud 24.224412500347043
# generación 540 tiene como mejor aptitud 24.224412500347043
# generación 541 tiene como mejor aptitud 24.224412500347043
# generación 542 tiene como mejor aptitud 24.224412500347043
# generación 543 tiene como mejor aptitud 24.224412500347043
# generación 544 tiene como mejor aptitud 24.224412500347043
# generación 545 tiene como mejor aptitud 24.224412500347043
# generación 546 tiene como mejor aptitud 24.224412500347043
# generación 547 tiene como mejor aptitud 24.224412500347043
# generación 548 tiene como mejor aptitud 24.224412500347043
# generación 549 tiene como mejor aptitud 24.224412500347043
# generación 550 tiene como mejor aptitud 24.224412500347043
# generación 551 tiene como mejor aptitud 24.224412500347043
# generación 552 tiene como mejor aptitud 24.224412500347043
# generación 553 tiene como mejor aptitud 24.224412500347043
# generación 554 tiene como mejor aptitud 24.224412500347043
# generación 555 tiene como mejor aptitud 24.224412500347043
# generación 556 tiene como mejor aptitud 24.224412500347043
# generación 557 tiene como mejor aptitud 24.224412500347043
# generación 558 tiene como mejor aptitud 24.224412500347043
# generación 559 tiene como mejor aptitud 24.224412500347043
# generación 560 tiene como mejor aptitud 24.224412500347043
# generación 561 tiene como mejor aptitud 24.224412500347043
# generación 562 tiene como mejor aptitud 24.224412500347043
# generación 563 tiene como mejor aptitud 24.224412500347043
# generación 564 tiene como mejor aptitud 24.224412500347043
# generación 565 tiene como mejor aptitud 24.224412500347043
# generación 566 tiene como mejor aptitud 24.224412500347043
# generación 567 tiene como mejor aptitud 24.224412500347043
# generación 568 tiene como mejor aptitud 24.224412500347043
# generación 569 tiene como mejor aptitud 24.224412500347043
# generación 570 tiene como mejor aptitud 24.224412500347043
# generación 571 tiene como mejor aptitud 24.224412500347043
# generación 572 tiene como mejor aptitud 24.224412500347043
# generación 573 tiene como mejor aptitud 24.224412500347043
# generación 574 tiene como mejor aptitud 24.224412500347043
# generación 575 tiene como mejor aptitud 24.224412500347043
# generación 576 tiene como mejor aptitud 24.224412500347043
# generación 577 tiene como mejor aptitud 24.224412500347043
# generación 578 tiene como mejor aptitud 24.224412500347043
# generación 579 tiene como mejor aptitud 24.224412500347043
# generación 580 tiene como mejor aptitud 24.224412500347043
# generación 581 tiene como mejor aptitud 24.224412500347043
# generación 582 tiene como mejor aptitud 24.224412500347043
# generación 583 tiene como mejor aptitud 24.224412500347043
# generación 584 tiene como mejor aptitud 24.224412500347043
# generación 585 tiene como mejor aptitud 24.224412500347043
# generación 586 tiene como mejor aptitud 24.224412500347043
# generación 587 tiene como mejor aptitud 24.224412500347043
# generación 588 tiene como mejor aptitud 24.224412500347043
# generación 589 tiene como mejor aptitud 24.224412500347043
# generación 590 tiene como mejor aptitud 24.224412500347043
# generación 591 tiene como mejor aptitud 24.224412500347043
# generación 592 tiene como mejor aptitud 24.224412500347043
# generación 593 tiene como mejor aptitud 24.224412500347043
# generación 594 tiene como mejor aptitud 24.224412500347043
# generación 595 tiene como mejor aptitud 24.224412500347043
# generación 596 tiene como mejor aptitud 24.224412500347043
# generación 597 tiene como mejor aptitud 24.224412500347043
# generación 598 tiene como mejor aptitud 24.224412500347043
# generación 599 tiene como mejor aptitud 24.224412500347043
# generación 600 tiene como mejor aptitud 24.224412500347043
# generación 601 tiene como mejor aptitud 24.224412500347043
# generación 602 tiene como mejor aptitud 24.224412500347043
# generación 603 tiene como mejor aptitud 24.224412500347043
# generación 604 tiene como mejor aptitud 24.224412500347043
# generación 605 tiene como mejor aptitud 24.224412500347043
# generación 606 tiene como mejor aptitud 24.224412500347043
# generación 607 tiene como mejor aptitud 24.224412500347043
# generación 608 tiene como mejor aptitud 24.224412500347043
# generación 609 tiene como mejor aptitud 24.224412500347043
# generación 610 tiene como mejor aptitud 24.224412500347043
# generación 611 tiene como mejor aptitud 24.224412500347043
# generación 612 tiene como mejor aptitud 24.224412500347043
# generación 613 tiene como mejor aptitud 24.224412500347043
# generación 614 tiene como mejor aptitud 24.224412500347043
# generación 615 tiene como mejor aptitud 24.224412500347043
# generación 616 tiene como mejor aptitud 24.224412500347043
# generación 617 tiene como mejor aptitud 24.224412500347043
# generación 618 tiene como mejor aptitud 24.224412500347043
# generación 619 tiene como mejor aptitud 24.224412500347043
# generación 620 tiene como mejor aptitud 24.224412500347043
# generación 621 tiene como mejor aptitud 24.224412500347043
# generación 622 tiene como mejor aptitud 24.224412500347043
# generación 623 tiene como mejor aptitud 24.224412500347043
# generación 624 tiene como mejor aptitud 24.224412500347043
# generación 625 tiene como mejor aptitud 24.224412500347043
# generación 626 tiene como mejor aptitud 24.224412500347043
# generación 627 tiene como mejor aptitud 24.224412500347043
# generación 628 tiene como mejor aptitud 24.224412500347043
# generación 629 tiene como mejor aptitud 24.224412500347043
# generación 630 tiene como mejor aptitud 24.224412500347043
# generación 631 tiene como mejor aptitud 24.224412500347043
# generación 632 tiene como mejor aptitud 24.224412500347043
# generación 633 tiene como mejor aptitud 24.224412500347043
# generación 634 tiene como mejor aptitud 24.224412500347043
# generación 635 tiene como mejor aptitud 24.224412500347043
# generación 636 tiene como mejor aptitud 24.224412500347043
# generación 637 tiene como mejor aptitud 24.224412500347043
# generación 638 tiene como mejor aptitud 24.224412500347043
# generación 639 tiene como mejor aptitud 24.224412500347043
# generación 640 tiene como mejor aptitud 24.224412500347043
# generación 641 tiene como mejor aptitud 24.224412500347043
# generación 642 tiene como mejor aptitud 24.224412500347043
# generación 643 tiene como mejor aptitud 24.224412500347043
# generación 644 tiene como mejor aptitud 24.224412500347043
# generación 645 tiene como mejor aptitud 24.224412500347043
# generación 646 tiene como mejor aptitud 24.224412500347043
# generación 647 tiene como mejor aptitud 24.224412500347043
# generación 648 tiene como mejor aptitud 24.224412500347043
# generación 649 tiene como mejor aptitud 24.224412500347043
# generación 650 tiene como mejor aptitud 24.224412500347043
# generación 651 tiene como mejor aptitud 24.224412500347043
# generación 652 tiene como mejor aptitud 24.224412500347043
# generación 653 tiene como mejor aptitud 24.224412500347043
# generación 654 tiene como mejor aptitud 24.224412500347043
# generación 655 tiene como mejor aptitud 24.224412500347043
# generación 656 tiene como mejor aptitud 24.224412500347043
# generación 657 tiene como mejor aptitud 24.224412500347043
# generación 658 tiene como mejor aptitud 24.224412500347043
# generación 659 tiene como mejor aptitud 24.224412500347043
# generación 660 tiene como mejor aptitud 24.224412500347043
# generación 661 tiene como mejor aptitud 24.224412500347043
# generación 662 tiene como mejor aptitud 24.224412500347043
# generación 663 tiene como mejor aptitud 24.224412500347043
# generación 664 tiene como mejor aptitud 24.224412500347043
# generación 665 tiene como mejor aptitud 24.224412500347043
# generación 666 tiene como mejor aptitud 24.224412500347043
# generación 667 tiene como mejor aptitud 24.224412500347043
# generación 668 tiene como mejor aptitud 24.224412500347043
# generación 669 tiene como mejor aptitud 24.224412500347043
# generación 670 tiene como mejor aptitud 24.224412500347043
# generación 671 tiene como mejor aptitud 24.224412500347043
# generación 672 tiene como mejor aptitud 24.224412500347043
# generación 673 tiene como mejor aptitud 24.224412500347043
# generación 674 tiene como mejor aptitud 24.224412500347043
# generación 675 tiene como mejor aptitud 24.224412500347043
# generación 676 tiene como mejor aptitud 24.224412500347043
# generación 677 tiene como mejor aptitud 24.224412500347043
# generación 678 tiene como mejor aptitud 24.224412500347043
# generación 679 tiene como mejor aptitud 24.224412500347043
# generación 680 tiene como mejor aptitud 24.224412500347043
# generación 681 tiene como mejor aptitud 24.224412500347043
# generación 682 tiene como mejor aptitud 24.224412500347043
# generación 683 tiene como mejor aptitud 24.224412500347043
# generación 684 tiene como mejor aptitud 24.224412500347043
# generación 685 tiene como mejor aptitud 24.224412500347043
# generación 686 tiene como mejor aptitud 24.224412500347043
# generación 687 tiene como mejor aptitud 24.224412500347043
# generación 688 tiene como mejor aptitud 24.224412500347043
# generación 689 tiene como mejor aptitud 24.224412500347043
# generación 690 tiene como mejor aptitud 24.224412500347043
# generación 691 tiene como mejor aptitud 24.224412500347043
# generación 692 tiene como mejor aptitud 24.224412500347043
# generación 693 tiene como mejor aptitud 24.224412500347043
# generación 694 tiene como mejor aptitud 24.224412500347043
# generación 695 tiene como mejor aptitud 24.224412500347043
# generación 696 tiene como mejor aptitud 24.224412500347043
# generación 697 tiene como mejor aptitud 24.224412500347043
# generación 698 tiene como mejor aptitud 24.224412500347043
# generación 699 tiene como mejor aptitud 24.224412500347043
# generación 700 tiene como mejor aptitud 24.224412500347043
# generación 701 tiene como mejor aptitud 24.224412500347043
# generación 702 tiene como mejor aptitud 24.224412500347043
# generación 703 tiene como mejor aptitud 24.224412500347043
# generación 704 tiene como mejor aptitud 24.224412500347043
# generación 705 tiene como mejor aptitud 24.224412500347043
# generación 706 tiene como mejor aptitud 24.224412500347043
# generación 707 tiene como mejor aptitud 24.224412500347043
# generación 708 tiene como mejor aptitud 24.224412500347043
# generación 709 tiene como mejor aptitud 24.224412500347043
# generación 710 tiene como mejor aptitud 24.224412500347043
# generación 711 tiene como mejor aptitud 24.224412500347043
# generación 712 tiene como mejor aptitud 24.224412500347043
# generación 713 tiene como mejor aptitud 24.224412500347043
# generación 714 tiene como mejor aptitud 24.224412500347043
# generación 715 tiene como mejor aptitud 24.224412500347043
# generación 716 tiene como mejor aptitud 24.224412500347043
# generación 717 tiene como mejor aptitud 24.224412500347043
# generación 718 tiene como mejor aptitud 24.224412500347043
# generación 719 tiene como mejor aptitud 24.224412500347043
# generación 720 tiene como mejor aptitud 24.224412500347043
# generación 721 tiene como mejor aptitud 24.224412500347043
# generación 722 tiene como mejor aptitud 24.224412500347043
# generación 723 tiene como mejor aptitud 24.224412500347043
# generación 724 tiene como mejor aptitud 24.224412500347043
# generación 725 tiene como mejor aptitud 24.224412500347043
# generación 726 tiene como mejor aptitud 24.224412500347043
# generación 727 tiene como mejor aptitud 24.224412500347043
# generación 728 tiene como mejor aptitud 24.224412500347043
# generación 729 tiene como mejor aptitud 24.224412500347043
# generación 730 tiene como mejor aptitud 24.224412500347043
# generación 731 tiene como mejor aptitud 24.224412500347043
# generación 732 tiene como mejor aptitud 24.224412500347043
# generación 733 tiene como mejor aptitud 24.224412500347043
# generación 734 tiene como mejor aptitud 24.224412500347043
# generación 735 tiene como mejor aptitud 24.224412500347043
# generación 736 tiene como mejor aptitud 24.224412500347043
# generación 737 tiene como mejor aptitud 24.224412500347043
# generación 738 tiene como mejor aptitud 24.224412500347043
# generación 739 tiene como mejor aptitud 24.224412500347043
# generación 740 tiene como mejor aptitud 24.224412500347043
# generación 741 tiene como mejor aptitud 24.224412500347043
# generación 742 tiene como mejor aptitud 24.224412500347043
# generación 743 tiene como mejor aptitud 24.224412500347043
# generación 744 tiene como mejor aptitud 24.224412500347043
# generación 745 tiene como mejor aptitud 24.224412500347043
# generación 746 tiene como mejor aptitud 24.224412500347043
# generación 747 tiene como mejor aptitud 24.224412500347043
# generación 748 tiene como mejor aptitud 24.224412500347043
# generación 749 tiene como mejor aptitud 24.224412500347043
# generación 750 tiene como mejor aptitud 24.224412500347043
# generación 751 tiene como mejor aptitud 24.224412500347043
# generación 752 tiene como mejor aptitud 24.224412500347043
# generación 753 tiene como mejor aptitud 24.224412500347043
# generación 754 tiene como mejor aptitud 24.224412500347043
# generación 755 tiene como mejor aptitud 24.224412500347043
# generación 756 tiene como mejor aptitud 24.224412500347043
# generación 757 tiene como mejor aptitud 24.224412500347043
# generación 758 tiene como mejor aptitud 24.224412500347043
# generación 759 tiene como mejor aptitud 24.224412500347043
# generación 760 tiene como mejor aptitud 24.224412500347043
# generación 761 tiene como mejor aptitud 24.224412500347043
# generación 762 tiene como mejor aptitud 24.224412500347043
# generación 763 tiene como mejor aptitud 24.224412500347043
# generación 764 tiene como mejor aptitud 24.224412500347043
# generación 765 tiene como mejor aptitud 24.224412500347043
# generación 766 tiene como mejor aptitud 24.224412500347043
# generación 767 tiene como mejor aptitud 24.224412500347043
# generación 768 tiene como mejor aptitud 24.224412500347043
# generación 769 tiene como mejor aptitud 24.224412500347043
# generación 770 tiene como mejor aptitud 24.224412500347043
# generación 771 tiene como mejor aptitud 24.224412500347043
# generación 772 tiene como mejor aptitud 24.224412500347043
# generación 773 tiene como mejor aptitud 24.224412500347043
# generación 774 tiene como mejor aptitud 24.224412500347043
# generación 775 tiene como mejor aptitud 24.224412500347043
# generación 776 tiene como mejor aptitud 24.224412500347043
# generación 777 tiene como mejor aptitud 24.224412500347043
# generación 778 tiene como mejor aptitud 24.224412500347043
# generación 779 tiene como mejor aptitud 24.224412500347043
# generación 780 tiene como mejor aptitud 24.224412500347043
# generación 781 tiene como mejor aptitud 24.224412500347043
# generación 782 tiene como mejor aptitud 24.224412500347043
# generación 783 tiene como mejor aptitud 24.224412500347043
# generación 784 tiene como mejor aptitud 24.224412500347043
# generación 785 tiene como mejor aptitud 24.224412500347043
# generación 786 tiene como mejor aptitud 24.224412500347043
# generación 787 tiene como mejor aptitud 24.224412500347043
# generación 788 tiene como mejor aptitud 24.224412500347043
# generación 789 tiene como mejor aptitud 24.224412500347043
# generación 790 tiene como mejor aptitud 24.224412500347043
# generación 791 tiene como mejor aptitud 24.224412500347043
# generación 792 tiene como mejor aptitud 24.224412500347043
# generación 793 tiene como mejor aptitud 24.224412500347043
# generación 794 tiene como mejor aptitud 24.224412500347043
# generación 795 tiene como mejor aptitud 24.224412500347043
# generación 796 tiene como mejor aptitud 24.224412500347043
# generación 797 tiene como mejor aptitud 24.224412500347043
# generación 798 tiene como mejor aptitud 24.224412500347043
# generación 799 tiene como mejor aptitud 24.224412500347043
# generación 800 tiene como mejor aptitud 24.224412500347043
# generación 801 tiene como mejor aptitud 24.224412500347043
# generación 802 tiene como mejor aptitud 24.224412500347043
# generación 803 tiene como mejor aptitud 24.224412500347043
# generación 804 tiene como mejor aptitud 24.224412500347043
# generación 805 tiene como mejor aptitud 24.224412500347043
# generación 806 tiene como mejor aptitud 24.224412500347043
# generación 807 tiene como mejor aptitud 24.224412500347043
# generación 808 tiene como mejor aptitud 24.224412500347043
# generación 809 tiene como mejor aptitud 24.224412500347043
# generación 810 tiene como mejor aptitud 24.224412500347043
# generación 811 tiene como mejor aptitud 24.224412500347043
# generación 812 tiene como mejor aptitud 24.224412500347043
# generación 813 tiene como mejor aptitud 24.224412500347043
# generación 814 tiene como mejor aptitud 24.224412500347043
# generación 815 tiene como mejor aptitud 24.224412500347043
# generación 816 tiene como mejor aptitud 24.224412500347043
# generación 817 tiene como mejor aptitud 24.224412500347043
# generación 818 tiene como mejor aptitud 24.224412500347043
# generación 819 tiene como mejor aptitud 24.224412500347043
# generación 820 tiene como mejor aptitud 24.224412500347043
# generación 821 tiene como mejor aptitud 24.224412500347043
# ...
# generación 2235 tiene como mejor aptitud 12.138945581174951
# generación 2236 tiene como mejor aptitud 12.138945581174951
# generación 2237 tiene como mejor aptitud 12.138945581174951
# generación 2238 tiene como mejor aptitud 12.138945581174951
# generación 2239 tiene como mejor aptitud 12.138945581174951
# generación 2240 tiene como mejor aptitud 12.138945581174951
# generación 2241 tiene como mejor aptitud 12.138945581174951
# generación 2242 tiene como mejor aptitud 12.138945581174951
# generación 2243 tiene como mejor aptitud 12.138945581174951
# generación 2244 tiene como mejor aptitud 12.138945581174951
# generación 2245 tiene como mejor aptitud 12.138945581174951
# generación 2246 tiene como mejor aptitud 12.138945581174951
# generación 2247 tiene como mejor aptitud 12.138945581174951
# generación 2248 tiene como mejor aptitud 12.138945581174951
# generación 2249 tiene como mejor aptitud 12.138945581174951
# generación 2250 tiene como mejor aptitud 12.138945581174951
# generación 2251 tiene como mejor aptitud 12.138945581174951
# generación 2252 tiene como mejor aptitud 12.138945581174951
# generación 2253 tiene como mejor aptitud 12.138945581174951
# generación 2254 tiene como mejor aptitud 12.138945581174951
# generación 2255 tiene como mejor aptitud 12.138945581174951
# generación 2256 tiene como mejor aptitud 12.138945581174951
# generación 2257 tiene como mejor aptitud 12.138945581174951
# generación 2258 tiene como mejor aptitud 12.138945581174951
# generación 2259 tiene como mejor aptitud 12.138945581174951
# generación 2260 tiene como mejor aptitud 12.138945581174951
# generación 2261 tiene como mejor aptitud 12.138945581174951
# generación 2262 tiene como mejor aptitud 12.138945581174951
# generación 2263 tiene como mejor aptitud 12.138945581174951
# generación 2264 tiene como mejor aptitud 12.138945581174951
# generación 2265 tiene como mejor aptitud 12.138945581174951
# generación 2266 tiene como mejor aptitud 12.138945581174951
# generación 2267 tiene como mejor aptitud 12.138945581174951
# generación 2268 tiene como mejor aptitud 12.138945581174951
# generación 2269 tiene como mejor aptitud 12.138945581174951
# generación 2270 tiene como mejor aptitud 12.138945581174951
# generación 2271 tiene como mejor aptitud 12.138945581174951
# generación 2272 tiene como mejor aptitud 12.138945581174951
# generación 2273 tiene como mejor aptitud 12.138945581174951
# generación 2274 tiene como mejor aptitud 12.138945581174951
# generación 2275 tiene como mejor aptitud 12.138945581174951
# generación 2276 tiene como mejor aptitud 12.138945581174951
# generación 2277 tiene como mejor aptitud 12.138945581174951
# generación 2278 tiene como mejor aptitud 12.138945581174951
# generación 2279 tiene como mejor aptitud 12.138945581174951
# generación 2280 tiene como mejor aptitud 12.138945581174951
# generación 2281 tiene como mejor aptitud 12.138945581174951
# generación 2282 tiene como mejor aptitud 12.138945581174951
# generación 2283 tiene como mejor aptitud 12.138945581174951
# generación 2284 tiene como mejor aptitud 12.138945581174951
# generación 2285 tiene como mejor aptitud 12.138945581174951
# generación 2286 tiene como mejor aptitud 12.138945581174951
# generación 2287 tiene como mejor aptitud 12.138945581174951
# generación 2288 tiene como mejor aptitud 12.138945581174951
# generación 2289 tiene como mejor aptitud 12.138945581174951
# generación 2290 tiene como mejor aptitud 12.138945581174951
# generación 2291 tiene como mejor aptitud 12.138945581174951
# generación 2292 tiene como mejor aptitud 12.138945581174951
# generación 2293 tiene como mejor aptitud 12.138945581174951
# generación 2294 tiene como mejor aptitud 12.138945581174951
# generación 2295 tiene como mejor aptitud 12.138945581174951
# generación 2296 tiene como mejor aptitud 12.138945581174951
# generación 2297 tiene como mejor aptitud 12.138945581174951
# generación 2298 tiene como mejor aptitud 12.138945581174951
# generación 2299 tiene como mejor aptitud 12.138945581174951
# generación 2300 tiene como mejor aptitud 12.138945581174951
# generación 2301 tiene como mejor aptitud 12.138945581174951
# generación 2302 tiene como mejor aptitud 12.138945581174951
# generación 2303 tiene como mejor aptitud 12.138945581174951
# generación 2304 tiene como mejor aptitud 12.138945581174951
# generación 2305 tiene como mejor aptitud 12.138945581174951
# generación 2306 tiene como mejor aptitud 12.138945581174951
# generación 2307 tiene como mejor aptitud 12.138945581174951
# generación 2308 tiene como mejor aptitud 12.138945581174951
# generación 2309 tiene como mejor aptitud 12.138945581174951
# generación 2310 tiene como mejor aptitud 12.138945581174951
# generación 2311 tiene como mejor aptitud 12.138945581174951
# generación 2312 tiene como mejor aptitud 12.138945581174951
# generación 2313 tiene como mejor aptitud 12.138945581174951
# generación 2314 tiene como mejor aptitud 12.138945581174951
# generación 2315 tiene como mejor aptitud 12.138945581174951
# generación 2316 tiene como mejor aptitud 12.138945581174951
# generación 2317 tiene como mejor aptitud 12.138945581174951
# generación 2318 tiene como mejor aptitud 12.138945581174951
# generación 2319 tiene como mejor aptitud 12.138945581174951
# generación 2320 tiene como mejor aptitud 12.138945581174951
# generación 2321 tiene como mejor aptitud 12.138945581174951
# generación 2322 tiene como mejor aptitud 12.138945581174951
# generación 2323 tiene como mejor aptitud 12.138945581174951
# generación 2324 tiene como mejor aptitud 12.138945581174951
# generación 2325 tiene como mejor aptitud 12.138945581174951
# generación 2326 tiene como mejor aptitud 12.138945581174951
# generación 2327 tiene como mejor aptitud 12.138945581174951
# generación 2328 tiene como mejor aptitud 12.138945581174951
# generación 2329 tiene como mejor aptitud 12.138945581174951
# generación 2330 tiene como mejor aptitud 12.138945581174951
# generación 2331 tiene como mejor aptitud 12.138945581174951
# generación 2332 tiene como mejor aptitud 12.138945581174951
# generación 2333 tiene como mejor aptitud 12.138945581174951
# generación 2334 tiene como mejor aptitud 12.138945581174951
# generación 2335 tiene como mejor aptitud 12.138945581174951
# generación 2336 tiene como mejor aptitud 12.138945581174951
# generación 2337 tiene como mejor aptitud 12.138945581174951
# generación 2338 tiene como mejor aptitud 12.138945581174951
# generación 2339 tiene como mejor aptitud 12.138945581174951
# generación 2340 tiene como mejor aptitud 12.138945581174951
# generación 2341 tiene como mejor aptitud 12.138945581174951
# generación 2342 tiene como mejor aptitud 12.138945581174951
# generación 2343 tiene como mejor aptitud 12.138945581174951
# generación 2344 tiene como mejor aptitud 12.138945581174951
# generación 2345 tiene como mejor aptitud 12.138945581174951
# generación 2346 tiene como mejor aptitud 12.138945581174951
# generación 2347 tiene como mejor aptitud 12.138945581174951
# generación 2348 tiene como mejor aptitud 12.138945581174951
# generación 2349 tiene como mejor aptitud 12.138945581174951
# generación 2350 tiene como mejor aptitud 12.138945581174951
# generación 2351 tiene como mejor aptitud 12.138945581174951
# generación 2352 tiene como mejor aptitud 12.138945581174951
# generación 2353 tiene como mejor aptitud 12.138945581174951
# generación 2354 tiene como mejor aptitud 12.138945581174951
# generación 2355 tiene como mejor aptitud 12.138945581174951
# generación 2356 tiene como mejor aptitud 12.138945581174951
# generación 2357 tiene como mejor aptitud 12.138945581174951
# generación 2358 tiene como mejor aptitud 12.138945581174951
# generación 2359 tiene como mejor aptitud 12.138945581174951
# generación 2360 tiene como mejor aptitud 12.138945581174951
# generación 2361 tiene como mejor aptitud 12.138945581174951
# generación 2362 tiene como mejor aptitud 12.138945581174951
# generación 2363 tiene como mejor aptitud 12.138945581174951
# generación 2364 tiene como mejor aptitud 12.138945581174951
# generación 2365 tiene como mejor aptitud 12.138945581174951
# generación 2366 tiene como mejor aptitud 12.138945581174951
# generación 2367 tiene como mejor aptitud 12.138945581174951
# generación 2368 tiene como mejor aptitud 12.138945581174951
# generación 2369 tiene como mejor aptitud 12.138945581174951
# generación 2370 tiene como mejor aptitud 12.138945581174951
# generación 2371 tiene como mejor aptitud 12.138945581174951
# generación 2372 tiene como mejor aptitud 12.138945581174951
# generación 2373 tiene como mejor aptitud 12.138945581174951
# generación 2374 tiene como mejor aptitud 12.138945581174951
# generación 2375 tiene como mejor aptitud 12.138945581174951
# generación 2376 tiene como mejor aptitud 12.138945581174951
# generación 2377 tiene como mejor aptitud 12.138945581174951
# generación 2378 tiene como mejor aptitud 12.138945581174951
# generación 2379 tiene como mejor aptitud 12.138945581174951
# generación 2380 tiene como mejor aptitud 12.138945581174951
# generación 2381 tiene como mejor aptitud 12.138945581174951
# generación 2382 tiene como mejor aptitud 12.138945581174951
# generación 2383 tiene como mejor aptitud 12.138945581174951
# generación 2384 tiene como mejor aptitud 12.138945581174951
# generación 2385 tiene como mejor aptitud 12.138945581174951
# generación 2386 tiene como mejor aptitud 12.138945581174951
# generación 2387 tiene como mejor aptitud 12.138945581174951
# generación 2388 tiene como mejor aptitud 12.138945581174951
# generación 2389 tiene como mejor aptitud 12.138945581174951
# generación 2390 tiene como mejor aptitud 12.138945581174951
# generación 2391 tiene como mejor aptitud 12.138945581174951
# generación 2392 tiene como mejor aptitud 12.138945581174951
# generación 2393 tiene como mejor aptitud 12.138945581174951
# generación 2394 tiene como mejor aptitud 12.138945581174951
# generación 2395 tiene como mejor aptitud 12.138945581174951
# generación 2396 tiene como mejor aptitud 12.138945581174951
# generación 2397 tiene como mejor aptitud 12.138945581174951
# generación 2398 tiene como mejor aptitud 12.138945581174951
# generación 2399 tiene como mejor aptitud 12.138945581174951
# generación 2400 tiene como mejor aptitud 12.138945581174951
# generación 2401 tiene como mejor aptitud 12.138945581174951
# generación 2402 tiene como mejor aptitud 12.138945581174951
# generación 2403 tiene como mejor aptitud 12.138945581174951
# generación 2404 tiene como mejor aptitud 12.138945581174951
# generación 2405 tiene como mejor aptitud 12.138945581174951
# generación 2406 tiene como mejor aptitud 12.138945581174951
# generación 2407 tiene como mejor aptitud 12.138945581174951
# generación 2408 tiene como mejor aptitud 12.138945581174951
# generación 2409 tiene como mejor aptitud 12.138945581174951
# generación 2410 tiene como mejor aptitud 12.138945581174951
# generación 2411 tiene como mejor aptitud 12.138945581174951
# generación 2412 tiene como mejor aptitud 12.138945581174951
# generación 2413 tiene como mejor aptitud 12.138945581174951
# generación 2414 tiene como mejor aptitud 12.138945581174951
# generación 2415 tiene como mejor aptitud 12.138945581174951
# generación 2416 tiene como mejor aptitud 12.138945581174951
# generación 2417 tiene como mejor aptitud 12.138945581174951
# generación 2418 tiene como mejor aptitud 12.138945581174951
# generación 2419 tiene como mejor aptitud 12.138945581174951
# generación 2420 tiene como mejor aptitud 12.138945581174951
# generación 2421 tiene como mejor aptitud 12.138945581174951
# generación 2422 tiene como mejor aptitud 12.138945581174951
# generación 2423 tiene como mejor aptitud 12.138945581174951
# generación 2424 tiene como mejor aptitud 12.138945581174951
# generación 2425 tiene como mejor aptitud 12.138945581174951
# generación 2426 tiene como mejor aptitud 12.138945581174951
# generación 2427 tiene como mejor aptitud 12.138945581174951
# generación 2428 tiene como mejor aptitud 12.138945581174951
# generación 2429 tiene como mejor aptitud 12.138945581174951
# generación 2430 tiene como mejor aptitud 12.138945581174951
# generación 2431 tiene como mejor aptitud 12.138945581174951
# generación 2432 tiene como mejor aptitud 12.138945581174951
# generación 2433 tiene como mejor aptitud 12.138945581174951
# generación 2434 tiene como mejor aptitud 12.138945581174951
# generación 2435 tiene como mejor aptitud 12.138945581174951
# generación 2436 tiene como mejor aptitud 12.138945581174951
# generación 2437 tiene como mejor aptitud 12.138945581174951
# generación 2438 tiene como mejor aptitud 12.138945581174951
# generación 2439 tiene como mejor aptitud 12.138945581174951
# generación 2440 tiene como mejor aptitud 12.138945581174951
# generación 2441 tiene como mejor aptitud 12.138945581174951
# generación 2442 tiene como mejor aptitud 12.138945581174951
# generación 2443 tiene como mejor aptitud 12.138945581174951
# generación 2444 tiene como mejor aptitud 12.138945581174951
# generación 2445 tiene como mejor aptitud 12.138945581174951
# generación 2446 tiene como mejor aptitud 12.138945581174951
# generación 2447 tiene como mejor aptitud 12.138945581174951
# generación 2448 tiene como mejor aptitud 12.138945581174951
# generación 2449 tiene como mejor aptitud 12.138945581174951
# generación 2450 tiene como mejor aptitud 12.138945581174951
# generación 2451 tiene como mejor aptitud 12.138945581174951
# generación 2452 tiene como mejor aptitud 12.138945581174951
# generación 2453 tiene como mejor aptitud 12.138945581174951
# generación 2454 tiene como mejor aptitud 12.138945581174951
# generación 2455 tiene como mejor aptitud 12.138945581174951
# generación 2456 tiene como mejor aptitud 12.138945581174951
# generación 2457 tiene como mejor aptitud 12.138945581174951
# generación 2458 tiene como mejor aptitud 12.138945581174951
# generación 2459 tiene como mejor aptitud 12.138945581174951
# generación 2460 tiene como mejor aptitud 12.138945581174951
# generación 2461 tiene como mejor aptitud 12.138945581174951
# generación 2462 tiene como mejor aptitud 12.138945581174951
# generación 2463 tiene como mejor aptitud 12.138945581174951
# generación 2464 tiene como mejor aptitud 12.138945581174951
# generación 2465 tiene como mejor aptitud 12.138945581174951
# generación 2466 tiene como mejor aptitud 12.138945581174951
# generación 2467 tiene como mejor aptitud 12.138945581174951
# generación 2468 tiene como mejor aptitud 12.138945581174951
# generación 2469 tiene como mejor aptitud 12.138945581174951
# generación 2470 tiene como mejor aptitud 12.138945581174951
# generación 2471 tiene como mejor aptitud 12.138945581174951
# generación 2472 tiene como mejor aptitud 12.138945581174951
# generación 2473 tiene como mejor aptitud 12.138945581174951
# generación 2474 tiene como mejor aptitud 12.138945581174951
# generación 2475 tiene como mejor aptitud 12.138945581174951
# generación 2476 tiene como mejor aptitud 12.138945581174951
# generación 2477 tiene como mejor aptitud 12.138945581174951
# generación 2478 tiene como mejor aptitud 12.138945581174951
# generación 2479 tiene como mejor aptitud 12.138945581174951
# generación 2480 tiene como mejor aptitud 12.138945581174951
# generación 2481 tiene como mejor aptitud 12.138945581174951
# generación 2482 tiene como mejor aptitud 12.138945581174951
# generación 2483 tiene como mejor aptitud 12.138945581174951
# generación 2484 tiene como mejor aptitud 12.138945581174951
# generación 2485 tiene como mejor aptitud 12.138945581174951
# generación 2486 tiene como mejor aptitud 12.138945581174951
# generación 2487 tiene como mejor aptitud 12.138945581174951
# generación 2488 tiene como mejor aptitud 12.138945581174951
# generación 2489 tiene como mejor aptitud 12.138945581174951
# generación 2490 tiene como mejor aptitud 12.138945581174951
# generación 2491 tiene como mejor aptitud 12.138945581174951
# generación 2492 tiene como mejor aptitud 12.138945581174951
# generación 2493 tiene como mejor aptitud 12.138945581174951
# generación 2494 tiene como mejor aptitud 12.138945581174951
# generación 2495 tiene como mejor aptitud 12.138945581174951
# generación 2496 tiene como mejor aptitud 12.138945581174951
# generación 2497 tiene como mejor aptitud 12.138945581174951
# generación 2498 tiene como mejor aptitud 12.138945581174951
# generación 2499 tiene como mejor aptitud 12.138945581174951
# generación 2500 tiene como mejor aptitud 12.138945581174951

# %%
print(aptitud(inpob[0]))
# Out:
# 12.138945581174951

# %%
plt.figure(figsize=(10, 5))  
plt.plot(resultados,  linestyle='-', color='b')
plt.title('Gráfico de convergencia')  
plt.xlabel('generación')  
plt.ylabel('mejor aptitud')  
plt.grid(True)

plt.show()

# %%
x = np.array([arr[0] for arr in inpob])
y = np.array([arr[1] for arr in inpob])
z = np.array([arr[2] for arr in inpob])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


scatter = ax.scatter(x, y,z,  alpha = 0.5)
plt.show()

# %%
# %matplotlib notebook
# from mpl_toolkits.mplot3d import Axes3D


# def funcion(x, y):
#     return 30 + (x**2 - 10 * np.cos(2 * np.pi * x)) + (y**2 - 10 * np.cos(2 * np.pi * y))


# x = np.linspace(-5.12, 5.12, 400)
# y = np.linspace(-5.12, 5.12, 400)
# X, Y = np.meshgrid(x, y)
# Z = funcion(X, Y)


# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z, cmap='hsv')


# ax.set_xlim([-5.12, 5.12])
# ax.set_ylim([-5.12, 5.12])
# ax.set_zlim([np.min(Z), np.max(Z)])


# ax.set_box_aspect([1,1,1])  


# plt.show()

# %%
vect = [np.array([1.2,2.69,-3.6]), np.array([2,9,8])]

# %%
[aptitud(x) for x in vect]
# Out:
# [130.3173455268468, 219.0]
