# %%
import numpy as np #para manejo de vectores
import matplotlib.pyplot as plt #para gráficas
import math # para operaciones matemáticas
import random #para números aleatorios

# %% [markdown]
# Valores iniciales:
# Los vectores son de dimensión $dim = 10$
#
# El dominio de cada coordenada es $[xmin,xmax] = [-10,10]$
#
# La población inicial es de 100 individuos
#
# Se generan vectores de manera aleatoria uniforme, considerando el artículo de Ono acerca de UNDX, el valor de la varianza para el eje principal es
# $$\sigma^2_\xi=\frac{1}{4}$$
# y para el espacio ortogonal:
# $$\sigma^2_\eta=\frac{2}{3(n-1)} =  \frac{2}{9}$$
#
# pues $n=dim =10$.
#
# Este es un algoritmo genético que sigue la propuesta de Ono:
# * Generar de manera aleatoria vectores de dimensión 10
# * Elegir dos individuos de manera aleatoria sin reemplazo
# * Generar decendencia aplicando UNDX a los individuos elegidos, se repite este proceso $n_c$ veces para crear $2\times n_c$ decendientes
# * Sobreviven dos individuos de la familia que contiene a los padres y su decendencia; uno es el mejor individuo y el otro es elegido mediante ruleta. Los elementos reemplazan a los padres en la población
# * Se repiten los pasos anteriores hasta algún criterio de paro

# %%
dim = 10
xmin = -10
xmax = 10

vareta = 0.074
varxi = 0.25

pobsize = 500
n_c = 20
pob_mut = 0.4
maxiter = 1000

# %%
########### Norma de un vector para ahorrar notación #################
def norma(v):
    return np.linalg.norm(v)

# %%
############ Generar vectores n dimensionales de manera aleatoria uniforme ##############
def create_pob(pobsize):
    pob = []
    for i in range(pobsize):
        vector = []
        for j in range(dim):
            x = random.uniform(-10,10)
            vector.append(x)            
        vector = np.array(vector)
        pob.append(vector)
    return pob

# %%
########## Función fitness a optimizar, hallar mínimo en este caso ###########
def aptitud(x):
    return np.sum(x**2)

# %%
##############################################################
# Calcula el complemento ortogonal de un vector              #
# El resultado es una base de n-1 elementos de dimension n   #
##############################################################
def orthogonal_vectors(base_vector, num_vectors = dim -1):
    vectors = []
    while len(vectors) < num_vectors:
        vec = np.random.rand(dim)
        for v in vectors + [base_vector]:
            epsilon = 1e-8  #np batalla para dividir entre números pequeños
            vec -= np.dot(vec, v) / (np.dot(v, v) + epsilon) * v #sumo un número pequeño para evitar errores
        if norma(vec) > 1e-5:  
            vectors.append(vec / norma(vec))  
    return np.array(vectors)

# %%
##############################################
# Genera el elemento del espacio ortogonal   #
# usando la varianza teorica                 #
##############################################

def gen_corth(base):
    vect = 0
    for i in base:
        etai = np.random.normal(0,np.sqrt(vareta))
        vect += etai * i
    return vect

# %%
def mut_uniform(childs, prob_mut):
    for child in childs:
        for i in range(len(child)):
            if np.random.rand() < prob_mut:
                child[i] = np.random.uniform(xmin,xmax)
    return childs

# %%
###############################################################
# Segun ono sobrevive el mejor y el que gane                  #
# ruleta, la ruleta esta basada en la aptitud                 #
# como se intenta minimizar tomo el inverso multiplicativo    #
# para que la menor aptitud tenga mayor probabilidad          #
# de ser elegida                                              #
###############################################################
def survival_selection(family):
    best = min(family, key=lambda individual: aptitud(individual))
    weights = [1.0 / (aptitud(ind) + 1e-6) for ind in family]  
    roulette_selection = random.choices(family, weights=weights, k=1)[0]
    return best, roulette_selection

# %%
#################################################################
# Operador undx, recibe a la población y arroja a la población  #
# con el reemplazo hecho por la ruleta  y el mejor              #
#################################################################
def undx(pob, n_c,pob_mut):
    epsilon = 1e-8
    padres = random.sample(pob, 3)
    x1, x2, x3 = padres
    xp = 0.5 * (x2 + x1)
    d = x2 - x1
    offspring = []

    for _ in range(n_c):
        x31 = x3 - x1
        x21 = x2 - x1
        D = math.sqrt(norma(x31)**2 * (1 - (np.dot(x31, x21) / (norma(x31) * norma(x21) + epsilon))**2))
        orth_vects = orthogonal_vectors(d, num_vectors=dim-1)
        comp_orth = gen_corth(orth_vects)
        xi = np.random.normal(0, np.sqrt(varxi))
        x_c = xp + xi * d + comp_orth
        x_c2 = xp - xi * d - comp_orth
        offspring.extend([x_c, x_c2])
        
        
    offspring = mut_uniform(offspring,pob_mut)

    family = [x1, x2, x3] + offspring
    best, roulette = survival_selection(family)

    for idx in range(len(pob)):
        if np.array_equal(pob[idx], x1):
            pob[idx] = best
            break

    for idx in range(len(pob)):
        if np.array_equal(pob[idx], x2):
            pob[idx] = roulette
            break

    sorted_pob = sorted(pob, key=lambda individual: aptitud(individual))

    return sorted_pob

# %%
inpob = create_pob(pobsize)
x = np.array([arr[0] for arr in inpob])
y = np.array([arr[1] for arr in inpob])
z = np.array([arr[2] for arr in inpob])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


scatter = ax.scatter(x, y, z, alpha =0.8)

ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_zlabel('Z Coordinate')

plt.show()

# %%
resultados= []
for i in range(maxiter):
    inpob = undx(inpob, n_c, pob_mut)
    print(f"generación {i+1} tiene como mejor aptitud {aptitud(inpob[0])}")
    resultados.append(aptitud(inpob[0]))
# Out:
# generación 1 tiene como mejor aptitud 88.1839218642804
# generación 2 tiene como mejor aptitud 88.1839218642804
# generación 3 tiene como mejor aptitud 88.1839218642804
# generación 4 tiene como mejor aptitud 88.1839218642804
# generación 5 tiene como mejor aptitud 88.1839218642804
# generación 6 tiene como mejor aptitud 70.88738883530675
# generación 7 tiene como mejor aptitud 61.87963485148164
# generación 8 tiene como mejor aptitud 61.87963485148164
# generación 9 tiene como mejor aptitud 61.87963485148164
# generación 10 tiene como mejor aptitud 61.87963485148164
# generación 11 tiene como mejor aptitud 61.87963485148164
# generación 12 tiene como mejor aptitud 61.87963485148164
# generación 13 tiene como mejor aptitud 61.87963485148164
# generación 14 tiene como mejor aptitud 61.87963485148164
# generación 15 tiene como mejor aptitud 61.87963485148164
# generación 16 tiene como mejor aptitud 61.87963485148164
# generación 17 tiene como mejor aptitud 61.87963485148164
# generación 18 tiene como mejor aptitud 37.43751814863247
# generación 19 tiene como mejor aptitud 37.43751814863247
# generación 20 tiene como mejor aptitud 37.43751814863247
# generación 21 tiene como mejor aptitud 37.43751814863247
# generación 22 tiene como mejor aptitud 37.43751814863247
# generación 23 tiene como mejor aptitud 37.43751814863247
# generación 24 tiene como mejor aptitud 37.43751814863247
# generación 25 tiene como mejor aptitud 37.43751814863247
# generación 26 tiene como mejor aptitud 37.43751814863247
# generación 27 tiene como mejor aptitud 37.43751814863247
# generación 28 tiene como mejor aptitud 37.43751814863247
# generación 29 tiene como mejor aptitud 37.43751814863247
# generación 30 tiene como mejor aptitud 37.43751814863247
# generación 31 tiene como mejor aptitud 37.43751814863247
# generación 32 tiene como mejor aptitud 37.43751814863247
# generación 33 tiene como mejor aptitud 37.43751814863247
# generación 34 tiene como mejor aptitud 37.43751814863247
# generación 35 tiene como mejor aptitud 37.43751814863247
# generación 36 tiene como mejor aptitud 37.43751814863247
# generación 37 tiene como mejor aptitud 37.43751814863247
# generación 38 tiene como mejor aptitud 37.43751814863247
# generación 39 tiene como mejor aptitud 37.43751814863247
# generación 40 tiene como mejor aptitud 37.43751814863247
# generación 41 tiene como mejor aptitud 37.43751814863247
# generación 42 tiene como mejor aptitud 37.43751814863247
# generación 43 tiene como mejor aptitud 37.43751814863247
# generación 44 tiene como mejor aptitud 37.43751814863247
# generación 45 tiene como mejor aptitud 37.43751814863247
# generación 46 tiene como mejor aptitud 37.43751814863247
# generación 47 tiene como mejor aptitud 37.43751814863247
# generación 48 tiene como mejor aptitud 37.43751814863247
# generación 49 tiene como mejor aptitud 37.43751814863247
# generación 50 tiene como mejor aptitud 37.43751814863247
# generación 51 tiene como mejor aptitud 37.43751814863247
# generación 52 tiene como mejor aptitud 37.43751814863247
# generación 53 tiene como mejor aptitud 37.43751814863247
# generación 54 tiene como mejor aptitud 37.43751814863247
# generación 55 tiene como mejor aptitud 37.43751814863247
# generación 56 tiene como mejor aptitud 37.43751814863247
# generación 57 tiene como mejor aptitud 37.43751814863247
# generación 58 tiene como mejor aptitud 37.43751814863247
# generación 59 tiene como mejor aptitud 37.43751814863247
# generación 60 tiene como mejor aptitud 37.43751814863247
# generación 61 tiene como mejor aptitud 37.43751814863247
# generación 62 tiene como mejor aptitud 37.43751814863247
# generación 63 tiene como mejor aptitud 37.43751814863247
# generación 64 tiene como mejor aptitud 37.43751814863247
# generación 65 tiene como mejor aptitud 37.43751814863247
# generación 66 tiene como mejor aptitud 37.43751814863247
# generación 67 tiene como mejor aptitud 37.43751814863247
# generación 68 tiene como mejor aptitud 37.43751814863247
# generación 69 tiene como mejor aptitud 37.43751814863247
# generación 70 tiene como mejor aptitud 37.43751814863247
# generación 71 tiene como mejor aptitud 37.43751814863247
# generación 72 tiene como mejor aptitud 37.43751814863247
# generación 73 tiene como mejor aptitud 37.43751814863247
# generación 74 tiene como mejor aptitud 37.43751814863247
# generación 75 tiene como mejor aptitud 37.43751814863247
# generación 76 tiene como mejor aptitud 37.43751814863247
# generación 77 tiene como mejor aptitud 37.43751814863247
# generación 78 tiene como mejor aptitud 26.37426555246824
# generación 79 tiene como mejor aptitud 26.37426555246824
# generación 80 tiene como mejor aptitud 26.37426555246824
# generación 81 tiene como mejor aptitud 26.37426555246824
# generación 82 tiene como mejor aptitud 26.37426555246824
# generación 83 tiene como mejor aptitud 26.37426555246824
# generación 84 tiene como mejor aptitud 26.37426555246824
# generación 85 tiene como mejor aptitud 26.37426555246824
# generación 86 tiene como mejor aptitud 26.37426555246824
# generación 87 tiene como mejor aptitud 17.045034715919304
# generación 88 tiene como mejor aptitud 17.045034715919304
# generación 89 tiene como mejor aptitud 17.045034715919304
# generación 90 tiene como mejor aptitud 17.045034715919304
# generación 91 tiene como mejor aptitud 17.045034715919304
# generación 92 tiene como mejor aptitud 17.045034715919304
# generación 93 tiene como mejor aptitud 17.045034715919304
# generación 94 tiene como mejor aptitud 17.045034715919304
# generación 95 tiene como mejor aptitud 17.045034715919304
# generación 96 tiene como mejor aptitud 17.045034715919304
# generación 97 tiene como mejor aptitud 17.045034715919304
# generación 98 tiene como mejor aptitud 17.045034715919304
# generación 99 tiene como mejor aptitud 17.045034715919304
# generación 100 tiene como mejor aptitud 17.045034715919304
# generación 101 tiene como mejor aptitud 17.045034715919304
# generación 102 tiene como mejor aptitud 17.045034715919304
# generación 103 tiene como mejor aptitud 17.045034715919304
# generación 104 tiene como mejor aptitud 17.045034715919304
# generación 105 tiene como mejor aptitud 17.045034715919304
# generación 106 tiene como mejor aptitud 17.045034715919304
# generación 107 tiene como mejor aptitud 17.045034715919304
# generación 108 tiene como mejor aptitud 17.045034715919304
# generación 109 tiene como mejor aptitud 17.045034715919304
# generación 110 tiene como mejor aptitud 17.045034715919304
# generación 111 tiene como mejor aptitud 17.045034715919304
# generación 112 tiene como mejor aptitud 17.045034715919304
# generación 113 tiene como mejor aptitud 17.045034715919304
# generación 114 tiene como mejor aptitud 17.045034715919304
# generación 115 tiene como mejor aptitud 17.045034715919304
# generación 116 tiene como mejor aptitud 17.045034715919304
# generación 117 tiene como mejor aptitud 17.045034715919304
# generación 118 tiene como mejor aptitud 17.045034715919304
# generación 119 tiene como mejor aptitud 17.045034715919304
# generación 120 tiene como mejor aptitud 17.045034715919304
# generación 121 tiene como mejor aptitud 17.045034715919304
# generación 122 tiene como mejor aptitud 17.045034715919304
# generación 123 tiene como mejor aptitud 17.045034715919304
# generación 124 tiene como mejor aptitud 17.045034715919304
# generación 125 tiene como mejor aptitud 17.045034715919304
# generación 126 tiene como mejor aptitud 17.045034715919304
# generación 127 tiene como mejor aptitud 17.045034715919304
# generación 128 tiene como mejor aptitud 17.045034715919304
# generación 129 tiene como mejor aptitud 17.045034715919304
# generación 130 tiene como mejor aptitud 17.045034715919304
# generación 131 tiene como mejor aptitud 17.045034715919304
# generación 132 tiene como mejor aptitud 17.045034715919304
# generación 133 tiene como mejor aptitud 17.045034715919304
# generación 134 tiene como mejor aptitud 17.045034715919304
# generación 135 tiene como mejor aptitud 17.045034715919304
# generación 136 tiene como mejor aptitud 17.045034715919304
# generación 137 tiene como mejor aptitud 17.045034715919304
# generación 138 tiene como mejor aptitud 17.045034715919304
# generación 139 tiene como mejor aptitud 17.045034715919304
# generación 140 tiene como mejor aptitud 17.045034715919304
# generación 141 tiene como mejor aptitud 17.045034715919304
# generación 142 tiene como mejor aptitud 17.045034715919304
# generación 143 tiene como mejor aptitud 17.045034715919304
# generación 144 tiene como mejor aptitud 17.045034715919304
# generación 145 tiene como mejor aptitud 17.045034715919304
# generación 146 tiene como mejor aptitud 17.045034715919304
# generación 147 tiene como mejor aptitud 17.045034715919304
# generación 148 tiene como mejor aptitud 17.045034715919304
# generación 149 tiene como mejor aptitud 17.045034715919304
# generación 150 tiene como mejor aptitud 17.045034715919304
# generación 151 tiene como mejor aptitud 17.045034715919304
# generación 152 tiene como mejor aptitud 17.045034715919304
# generación 153 tiene como mejor aptitud 17.045034715919304
# generación 154 tiene como mejor aptitud 17.045034715919304
# generación 155 tiene como mejor aptitud 17.045034715919304
# generación 156 tiene como mejor aptitud 17.045034715919304
# generación 157 tiene como mejor aptitud 17.045034715919304
# generación 158 tiene como mejor aptitud 17.045034715919304
# generación 159 tiene como mejor aptitud 17.045034715919304
# generación 160 tiene como mejor aptitud 17.045034715919304
# generación 161 tiene como mejor aptitud 17.045034715919304
# generación 162 tiene como mejor aptitud 17.045034715919304
# generación 163 tiene como mejor aptitud 17.045034715919304
# generación 164 tiene como mejor aptitud 17.045034715919304
# generación 165 tiene como mejor aptitud 17.045034715919304
# generación 166 tiene como mejor aptitud 17.045034715919304
# generación 167 tiene como mejor aptitud 17.045034715919304
# generación 168 tiene como mejor aptitud 17.045034715919304
# generación 169 tiene como mejor aptitud 17.045034715919304
# generación 170 tiene como mejor aptitud 17.045034715919304
# generación 171 tiene como mejor aptitud 17.045034715919304
# generación 172 tiene como mejor aptitud 17.045034715919304
# generación 173 tiene como mejor aptitud 17.045034715919304
# generación 174 tiene como mejor aptitud 17.045034715919304
# generación 175 tiene como mejor aptitud 17.045034715919304
# generación 176 tiene como mejor aptitud 17.045034715919304
# generación 177 tiene como mejor aptitud 17.045034715919304
# generación 178 tiene como mejor aptitud 17.045034715919304
# generación 179 tiene como mejor aptitud 17.045034715919304
# generación 180 tiene como mejor aptitud 17.045034715919304
# generación 181 tiene como mejor aptitud 17.045034715919304
# generación 182 tiene como mejor aptitud 17.045034715919304
# generación 183 tiene como mejor aptitud 17.045034715919304
# generación 184 tiene como mejor aptitud 17.045034715919304
# generación 185 tiene como mejor aptitud 17.045034715919304
# generación 186 tiene como mejor aptitud 17.045034715919304
# generación 187 tiene como mejor aptitud 17.045034715919304
# generación 188 tiene como mejor aptitud 17.045034715919304
# generación 189 tiene como mejor aptitud 17.045034715919304
# generación 190 tiene como mejor aptitud 17.045034715919304
# generación 191 tiene como mejor aptitud 17.045034715919304
# generación 192 tiene como mejor aptitud 17.045034715919304
# generación 193 tiene como mejor aptitud 17.045034715919304
# generación 194 tiene como mejor aptitud 17.045034715919304
# generación 195 tiene como mejor aptitud 17.045034715919304
# generación 196 tiene como mejor aptitud 17.045034715919304
# generación 197 tiene como mejor aptitud 17.045034715919304
# generación 198 tiene como mejor aptitud 17.045034715919304
# generación 199 tiene como mejor aptitud 17.045034715919304
# generación 200 tiene como mejor aptitud 17.045034715919304
# generación 201 tiene como mejor aptitud 17.045034715919304
# generación 202 tiene como mejor aptitud 17.045034715919304
# generación 203 tiene como mejor aptitud 17.045034715919304
# generación 204 tiene como mejor aptitud 17.045034715919304
# generación 205 tiene como mejor aptitud 17.045034715919304
# generación 206 tiene como mejor aptitud 17.045034715919304
# generación 207 tiene como mejor aptitud 17.045034715919304
# generación 208 tiene como mejor aptitud 17.045034715919304
# generación 209 tiene como mejor aptitud 17.045034715919304
# generación 210 tiene como mejor aptitud 17.045034715919304
# generación 211 tiene como mejor aptitud 17.045034715919304
# generación 212 tiene como mejor aptitud 17.045034715919304
# generación 213 tiene como mejor aptitud 17.045034715919304
# generación 214 tiene como mejor aptitud 17.045034715919304
# generación 215 tiene como mejor aptitud 17.045034715919304
# generación 216 tiene como mejor aptitud 17.045034715919304
# generación 217 tiene como mejor aptitud 17.045034715919304
# generación 218 tiene como mejor aptitud 17.045034715919304
# generación 219 tiene como mejor aptitud 17.045034715919304
# generación 220 tiene como mejor aptitud 17.045034715919304
# generación 221 tiene como mejor aptitud 17.045034715919304
# generación 222 tiene como mejor aptitud 17.045034715919304
# generación 223 tiene como mejor aptitud 17.045034715919304
# generación 224 tiene como mejor aptitud 17.045034715919304
# generación 225 tiene como mejor aptitud 17.045034715919304
# generación 226 tiene como mejor aptitud 17.045034715919304
# generación 227 tiene como mejor aptitud 17.045034715919304
# generación 228 tiene como mejor aptitud 17.045034715919304
# generación 229 tiene como mejor aptitud 17.045034715919304
# generación 230 tiene como mejor aptitud 17.045034715919304
# generación 231 tiene como mejor aptitud 17.045034715919304
# generación 232 tiene como mejor aptitud 17.045034715919304
# generación 233 tiene como mejor aptitud 17.045034715919304
# generación 234 tiene como mejor aptitud 17.045034715919304
# generación 235 tiene como mejor aptitud 17.045034715919304
# generación 236 tiene como mejor aptitud 17.045034715919304
# generación 237 tiene como mejor aptitud 17.045034715919304
# generación 238 tiene como mejor aptitud 17.045034715919304
# generación 239 tiene como mejor aptitud 17.045034715919304
# generación 240 tiene como mejor aptitud 17.045034715919304
# generación 241 tiene como mejor aptitud 17.045034715919304
# generación 242 tiene como mejor aptitud 17.045034715919304
# generación 243 tiene como mejor aptitud 17.045034715919304
# generación 244 tiene como mejor aptitud 17.045034715919304
# generación 245 tiene como mejor aptitud 17.045034715919304
# generación 246 tiene como mejor aptitud 17.045034715919304
# generación 247 tiene como mejor aptitud 17.045034715919304
# generación 248 tiene como mejor aptitud 17.045034715919304
# generación 249 tiene como mejor aptitud 17.045034715919304
# generación 250 tiene como mejor aptitud 17.045034715919304
# generación 251 tiene como mejor aptitud 17.045034715919304
# generación 252 tiene como mejor aptitud 17.045034715919304
# generación 253 tiene como mejor aptitud 17.045034715919304
# generación 254 tiene como mejor aptitud 17.045034715919304
# generación 255 tiene como mejor aptitud 17.045034715919304
# generación 256 tiene como mejor aptitud 17.045034715919304
# generación 257 tiene como mejor aptitud 17.045034715919304
# generación 258 tiene como mejor aptitud 17.045034715919304
# generación 259 tiene como mejor aptitud 17.045034715919304
# generación 260 tiene como mejor aptitud 17.045034715919304
# generación 261 tiene como mejor aptitud 17.045034715919304
# generación 262 tiene como mejor aptitud 17.045034715919304
# generación 263 tiene como mejor aptitud 17.045034715919304
# generación 264 tiene como mejor aptitud 17.045034715919304
# generación 265 tiene como mejor aptitud 17.045034715919304
# generación 266 tiene como mejor aptitud 17.045034715919304
# generación 267 tiene como mejor aptitud 17.045034715919304
# generación 268 tiene como mejor aptitud 17.045034715919304
# generación 269 tiene como mejor aptitud 17.045034715919304
# generación 270 tiene como mejor aptitud 17.045034715919304
# generación 271 tiene como mejor aptitud 17.045034715919304
# generación 272 tiene como mejor aptitud 17.045034715919304
# generación 273 tiene como mejor aptitud 17.045034715919304
# generación 274 tiene como mejor aptitud 17.045034715919304
# generación 275 tiene como mejor aptitud 17.045034715919304
# generación 276 tiene como mejor aptitud 17.045034715919304
# generación 277 tiene como mejor aptitud 17.045034715919304
# generación 278 tiene como mejor aptitud 17.045034715919304
# generación 279 tiene como mejor aptitud 17.045034715919304
# generación 280 tiene como mejor aptitud 17.045034715919304
# generación 281 tiene como mejor aptitud 17.045034715919304
# generación 282 tiene como mejor aptitud 17.045034715919304
# generación 283 tiene como mejor aptitud 17.045034715919304
# generación 284 tiene como mejor aptitud 17.045034715919304
# generación 285 tiene como mejor aptitud 17.045034715919304
# generación 286 tiene como mejor aptitud 17.045034715919304
# generación 287 tiene como mejor aptitud 17.045034715919304
# generación 288 tiene como mejor aptitud 17.045034715919304
# generación 289 tiene como mejor aptitud 17.045034715919304
# generación 290 tiene como mejor aptitud 17.045034715919304
# generación 291 tiene como mejor aptitud 17.045034715919304
# generación 292 tiene como mejor aptitud 17.045034715919304
# generación 293 tiene como mejor aptitud 17.045034715919304
# generación 294 tiene como mejor aptitud 17.045034715919304
# generación 295 tiene como mejor aptitud 17.045034715919304
# generación 296 tiene como mejor aptitud 17.045034715919304
# generación 297 tiene como mejor aptitud 17.045034715919304
# generación 298 tiene como mejor aptitud 17.045034715919304
# generación 299 tiene como mejor aptitud 17.045034715919304
# generación 300 tiene como mejor aptitud 17.045034715919304
# generación 301 tiene como mejor aptitud 17.045034715919304
# generación 302 tiene como mejor aptitud 17.045034715919304
# generación 303 tiene como mejor aptitud 17.045034715919304
# generación 304 tiene como mejor aptitud 17.045034715919304
# generación 305 tiene como mejor aptitud 17.045034715919304
# generación 306 tiene como mejor aptitud 17.045034715919304
# generación 307 tiene como mejor aptitud 17.045034715919304
# generación 308 tiene como mejor aptitud 17.045034715919304
# generación 309 tiene como mejor aptitud 17.045034715919304
# generación 310 tiene como mejor aptitud 17.045034715919304
# generación 311 tiene como mejor aptitud 17.045034715919304
# generación 312 tiene como mejor aptitud 17.045034715919304
# generación 313 tiene como mejor aptitud 17.045034715919304
# generación 314 tiene como mejor aptitud 17.045034715919304
# generación 315 tiene como mejor aptitud 17.045034715919304
# generación 316 tiene como mejor aptitud 17.045034715919304
# generación 317 tiene como mejor aptitud 17.045034715919304
# generación 318 tiene como mejor aptitud 17.045034715919304
# generación 319 tiene como mejor aptitud 17.045034715919304
# generación 320 tiene como mejor aptitud 17.045034715919304
# generación 321 tiene como mejor aptitud 17.045034715919304
# generación 322 tiene como mejor aptitud 17.045034715919304
# generación 323 tiene como mejor aptitud 17.045034715919304
# generación 324 tiene como mejor aptitud 17.045034715919304
# generación 325 tiene como mejor aptitud 17.045034715919304
# generación 326 tiene como mejor aptitud 17.045034715919304
# generación 327 tiene como mejor aptitud 17.045034715919304
# generación 328 tiene como mejor aptitud 17.045034715919304
# generación 329 tiene como mejor aptitud 17.045034715919304
# generación 330 tiene como mejor aptitud 17.045034715919304
# generación 331 tiene como mejor aptitud 17.045034715919304
# generación 332 tiene como mejor aptitud 17.045034715919304
# generación 333 tiene como mejor aptitud 17.045034715919304
# generación 334 tiene como mejor aptitud 17.045034715919304
# generación 335 tiene como mejor aptitud 17.045034715919304
# generación 336 tiene como mejor aptitud 17.045034715919304
# generación 337 tiene como mejor aptitud 17.045034715919304
# generación 338 tiene como mejor aptitud 17.045034715919304
# generación 339 tiene como mejor aptitud 17.045034715919304
# generación 340 tiene como mejor aptitud 17.045034715919304
# generación 341 tiene como mejor aptitud 17.045034715919304
# generación 342 tiene como mejor aptitud 17.045034715919304
# generación 343 tiene como mejor aptitud 17.045034715919304
# generación 344 tiene como mejor aptitud 17.045034715919304
# generación 345 tiene como mejor aptitud 17.045034715919304
# generación 346 tiene como mejor aptitud 17.045034715919304
# generación 347 tiene como mejor aptitud 17.045034715919304
# generación 348 tiene como mejor aptitud 17.045034715919304
# generación 349 tiene como mejor aptitud 9.264958503002427
# generación 350 tiene como mejor aptitud 9.264958503002427
# generación 351 tiene como mejor aptitud 9.264958503002427
# generación 352 tiene como mejor aptitud 9.264958503002427
# generación 353 tiene como mejor aptitud 9.264958503002427
# generación 354 tiene como mejor aptitud 9.264958503002427
# generación 355 tiene como mejor aptitud 9.264958503002427
# generación 356 tiene como mejor aptitud 9.264958503002427
# generación 357 tiene como mejor aptitud 9.264958503002427
# generación 358 tiene como mejor aptitud 9.264958503002427
# generación 359 tiene como mejor aptitud 9.264958503002427
# generación 360 tiene como mejor aptitud 9.264958503002427
# generación 361 tiene como mejor aptitud 9.264958503002427
# generación 362 tiene como mejor aptitud 9.264958503002427
# generación 363 tiene como mejor aptitud 9.264958503002427
# generación 364 tiene como mejor aptitud 9.264958503002427
# generación 365 tiene como mejor aptitud 9.264958503002427
# generación 366 tiene como mejor aptitud 9.264958503002427
# generación 367 tiene como mejor aptitud 9.264958503002427
# generación 368 tiene como mejor aptitud 9.264958503002427
# generación 369 tiene como mejor aptitud 9.264958503002427
# generación 370 tiene como mejor aptitud 9.264958503002427
# generación 371 tiene como mejor aptitud 9.264958503002427
# generación 372 tiene como mejor aptitud 9.264958503002427
# generación 373 tiene como mejor aptitud 9.264958503002427
# generación 374 tiene como mejor aptitud 9.264958503002427
# generación 375 tiene como mejor aptitud 9.264958503002427
# generación 376 tiene como mejor aptitud 9.264958503002427
# generación 377 tiene como mejor aptitud 9.264958503002427
# generación 378 tiene como mejor aptitud 9.264958503002427
# generación 379 tiene como mejor aptitud 9.264958503002427
# generación 380 tiene como mejor aptitud 9.264958503002427
# generación 381 tiene como mejor aptitud 9.264958503002427
# generación 382 tiene como mejor aptitud 9.264958503002427
# generación 383 tiene como mejor aptitud 9.264958503002427
# generación 384 tiene como mejor aptitud 9.264958503002427
# generación 385 tiene como mejor aptitud 9.264958503002427
# generación 386 tiene como mejor aptitud 9.264958503002427
# generación 387 tiene como mejor aptitud 9.264958503002427
# generación 388 tiene como mejor aptitud 9.264958503002427
# generación 389 tiene como mejor aptitud 9.264958503002427
# generación 390 tiene como mejor aptitud 9.264958503002427
# generación 391 tiene como mejor aptitud 9.264958503002427
# generación 392 tiene como mejor aptitud 9.264958503002427
# generación 393 tiene como mejor aptitud 9.264958503002427
# generación 394 tiene como mejor aptitud 9.264958503002427
# generación 395 tiene como mejor aptitud 9.264958503002427
# generación 396 tiene como mejor aptitud 9.264958503002427
# generación 397 tiene como mejor aptitud 9.264958503002427
# generación 398 tiene como mejor aptitud 9.264958503002427
# generación 399 tiene como mejor aptitud 9.264958503002427
# generación 400 tiene como mejor aptitud 9.264958503002427
# generación 401 tiene como mejor aptitud 9.264958503002427
# generación 402 tiene como mejor aptitud 9.264958503002427
# generación 403 tiene como mejor aptitud 9.264958503002427
# generación 404 tiene como mejor aptitud 9.264958503002427
# generación 405 tiene como mejor aptitud 9.264958503002427
# generación 406 tiene como mejor aptitud 9.264958503002427
# generación 407 tiene como mejor aptitud 9.264958503002427
# generación 408 tiene como mejor aptitud 9.264958503002427
# generación 409 tiene como mejor aptitud 9.264958503002427
# generación 410 tiene como mejor aptitud 9.264958503002427
# generación 411 tiene como mejor aptitud 9.264958503002427
# generación 412 tiene como mejor aptitud 9.264958503002427
# generación 413 tiene como mejor aptitud 9.264958503002427
# generación 414 tiene como mejor aptitud 9.264958503002427
# generación 415 tiene como mejor aptitud 9.264958503002427
# generación 416 tiene como mejor aptitud 9.264958503002427
# generación 417 tiene como mejor aptitud 9.264958503002427
# generación 418 tiene como mejor aptitud 9.264958503002427
# generación 419 tiene como mejor aptitud 9.264958503002427
# generación 420 tiene como mejor aptitud 9.264958503002427
# generación 421 tiene como mejor aptitud 9.264958503002427
# generación 422 tiene como mejor aptitud 9.264958503002427
# generación 423 tiene como mejor aptitud 9.264958503002427
# generación 424 tiene como mejor aptitud 9.264958503002427
# generación 425 tiene como mejor aptitud 9.264958503002427
# generación 426 tiene como mejor aptitud 9.264958503002427
# generación 427 tiene como mejor aptitud 9.264958503002427
# generación 428 tiene como mejor aptitud 9.264958503002427
# generación 429 tiene como mejor aptitud 9.264958503002427
# generación 430 tiene como mejor aptitud 9.264958503002427
# generación 431 tiene como mejor aptitud 9.264958503002427
# generación 432 tiene como mejor aptitud 9.264958503002427
# generación 433 tiene como mejor aptitud 9.264958503002427
# generación 434 tiene como mejor aptitud 9.264958503002427
# generación 435 tiene como mejor aptitud 9.264958503002427
# generación 436 tiene como mejor aptitud 9.264958503002427
# generación 437 tiene como mejor aptitud 9.264958503002427
# generación 438 tiene como mejor aptitud 9.264958503002427
# generación 439 tiene como mejor aptitud 9.264958503002427
# generación 440 tiene como mejor aptitud 9.264958503002427
# generación 441 tiene como mejor aptitud 9.264958503002427
# generación 442 tiene como mejor aptitud 9.264958503002427
# generación 443 tiene como mejor aptitud 9.264958503002427
# generación 444 tiene como mejor aptitud 9.264958503002427
# generación 445 tiene como mejor aptitud 9.264958503002427
# generación 446 tiene como mejor aptitud 9.264958503002427
# generación 447 tiene como mejor aptitud 9.264958503002427
# generación 448 tiene como mejor aptitud 9.264958503002427
# generación 449 tiene como mejor aptitud 9.264958503002427
# generación 450 tiene como mejor aptitud 9.264958503002427
# generación 451 tiene como mejor aptitud 9.264958503002427
# generación 452 tiene como mejor aptitud 9.264958503002427
# generación 453 tiene como mejor aptitud 9.264958503002427
# generación 454 tiene como mejor aptitud 9.264958503002427
# generación 455 tiene como mejor aptitud 9.264958503002427
# generación 456 tiene como mejor aptitud 9.264958503002427
# generación 457 tiene como mejor aptitud 9.264958503002427
# generación 458 tiene como mejor aptitud 9.264958503002427
# generación 459 tiene como mejor aptitud 9.264958503002427
# generación 460 tiene como mejor aptitud 9.264958503002427
# generación 461 tiene como mejor aptitud 9.264958503002427
# generación 462 tiene como mejor aptitud 9.264958503002427
# generación 463 tiene como mejor aptitud 9.264958503002427
# generación 464 tiene como mejor aptitud 9.264958503002427
# generación 465 tiene como mejor aptitud 9.264958503002427
# generación 466 tiene como mejor aptitud 9.264958503002427
# generación 467 tiene como mejor aptitud 9.264958503002427
# generación 468 tiene como mejor aptitud 9.264958503002427
# generación 469 tiene como mejor aptitud 9.264958503002427
# generación 470 tiene como mejor aptitud 9.264958503002427
# generación 471 tiene como mejor aptitud 9.264958503002427
# generación 472 tiene como mejor aptitud 9.264958503002427
# generación 473 tiene como mejor aptitud 9.264958503002427
# generación 474 tiene como mejor aptitud 9.264958503002427
# generación 475 tiene como mejor aptitud 9.264958503002427
# generación 476 tiene como mejor aptitud 9.264958503002427
# generación 477 tiene como mejor aptitud 9.264958503002427
# generación 478 tiene como mejor aptitud 9.264958503002427
# generación 479 tiene como mejor aptitud 9.264958503002427
# generación 480 tiene como mejor aptitud 9.264958503002427
# generación 481 tiene como mejor aptitud 9.264958503002427
# generación 482 tiene como mejor aptitud 9.264958503002427
# generación 483 tiene como mejor aptitud 9.264958503002427
# generación 484 tiene como mejor aptitud 9.264958503002427
# generación 485 tiene como mejor aptitud 9.264958503002427
# generación 486 tiene como mejor aptitud 9.264958503002427
# generación 487 tiene como mejor aptitud 9.264958503002427
# generación 488 tiene como mejor aptitud 9.264958503002427
# generación 489 tiene como mejor aptitud 9.264958503002427
# generación 490 tiene como mejor aptitud 9.264958503002427
# generación 491 tiene como mejor aptitud 9.264958503002427
# generación 492 tiene como mejor aptitud 9.264958503002427
# generación 493 tiene como mejor aptitud 9.264958503002427
# generación 494 tiene como mejor aptitud 9.264958503002427
# generación 495 tiene como mejor aptitud 9.264958503002427
# generación 496 tiene como mejor aptitud 9.264958503002427
# generación 497 tiene como mejor aptitud 9.264958503002427
# generación 498 tiene como mejor aptitud 9.264958503002427
# generación 499 tiene como mejor aptitud 9.264958503002427
# generación 500 tiene como mejor aptitud 9.264958503002427
# generación 501 tiene como mejor aptitud 9.264958503002427
# generación 502 tiene como mejor aptitud 9.264958503002427
# generación 503 tiene como mejor aptitud 9.264958503002427
# generación 504 tiene como mejor aptitud 9.264958503002427
# generación 505 tiene como mejor aptitud 9.264958503002427
# generación 506 tiene como mejor aptitud 9.264958503002427
# generación 507 tiene como mejor aptitud 9.264958503002427
# generación 508 tiene como mejor aptitud 9.264958503002427
# generación 509 tiene como mejor aptitud 9.264958503002427
# generación 510 tiene como mejor aptitud 9.264958503002427
# generación 511 tiene como mejor aptitud 9.264958503002427
# generación 512 tiene como mejor aptitud 9.264958503002427
# generación 513 tiene como mejor aptitud 9.264958503002427
# generación 514 tiene como mejor aptitud 9.264958503002427
# generación 515 tiene como mejor aptitud 9.264958503002427
# generación 516 tiene como mejor aptitud 9.264958503002427
# generación 517 tiene como mejor aptitud 9.264958503002427
# generación 518 tiene como mejor aptitud 9.264958503002427
# generación 519 tiene como mejor aptitud 9.264958503002427
# generación 520 tiene como mejor aptitud 9.264958503002427
# generación 521 tiene como mejor aptitud 9.264958503002427
# generación 522 tiene como mejor aptitud 9.264958503002427
# generación 523 tiene como mejor aptitud 9.264958503002427
# generación 524 tiene como mejor aptitud 9.264958503002427
# generación 525 tiene como mejor aptitud 9.264958503002427
# generación 526 tiene como mejor aptitud 9.264958503002427
# generación 527 tiene como mejor aptitud 9.264958503002427
# generación 528 tiene como mejor aptitud 9.264958503002427
# generación 529 tiene como mejor aptitud 9.264958503002427
# generación 530 tiene como mejor aptitud 9.264958503002427
# generación 531 tiene como mejor aptitud 9.264958503002427
# generación 532 tiene como mejor aptitud 9.264958503002427
# generación 533 tiene como mejor aptitud 9.264958503002427
# generación 534 tiene como mejor aptitud 9.264958503002427
# generación 535 tiene como mejor aptitud 9.264958503002427
# generación 536 tiene como mejor aptitud 9.264958503002427
# generación 537 tiene como mejor aptitud 9.264958503002427
# generación 538 tiene como mejor aptitud 9.264958503002427
# generación 539 tiene como mejor aptitud 9.264958503002427
# generación 540 tiene como mejor aptitud 9.264958503002427
# generación 541 tiene como mejor aptitud 9.264958503002427
# generación 542 tiene como mejor aptitud 9.264958503002427
# generación 543 tiene como mejor aptitud 9.264958503002427
# generación 544 tiene como mejor aptitud 9.264958503002427
# generación 545 tiene como mejor aptitud 9.264958503002427
# generación 546 tiene como mejor aptitud 9.264958503002427
# generación 547 tiene como mejor aptitud 9.264958503002427
# generación 548 tiene como mejor aptitud 9.264958503002427
# generación 549 tiene como mejor aptitud 9.264958503002427
# generación 550 tiene como mejor aptitud 9.264958503002427
# generación 551 tiene como mejor aptitud 9.264958503002427
# generación 552 tiene como mejor aptitud 9.264958503002427
# generación 553 tiene como mejor aptitud 9.264958503002427
# generación 554 tiene como mejor aptitud 9.264958503002427
# generación 555 tiene como mejor aptitud 9.264958503002427
# generación 556 tiene como mejor aptitud 9.264958503002427
# generación 557 tiene como mejor aptitud 9.264958503002427
# generación 558 tiene como mejor aptitud 9.264958503002427
# generación 559 tiene como mejor aptitud 9.264958503002427
# generación 560 tiene como mejor aptitud 9.264958503002427
# generación 561 tiene como mejor aptitud 9.264958503002427
# generación 562 tiene como mejor aptitud 9.264958503002427
# generación 563 tiene como mejor aptitud 9.264958503002427
# generación 564 tiene como mejor aptitud 9.264958503002427
# generación 565 tiene como mejor aptitud 9.264958503002427
# generación 566 tiene como mejor aptitud 9.264958503002427
# generación 567 tiene como mejor aptitud 9.264958503002427
# generación 568 tiene como mejor aptitud 9.264958503002427
# generación 569 tiene como mejor aptitud 9.264958503002427
# generación 570 tiene como mejor aptitud 9.264958503002427
# generación 571 tiene como mejor aptitud 9.264958503002427
# generación 572 tiene como mejor aptitud 9.264958503002427
# generación 573 tiene como mejor aptitud 9.264958503002427
# generación 574 tiene como mejor aptitud 9.264958503002427
# generación 575 tiene como mejor aptitud 9.264958503002427
# generación 576 tiene como mejor aptitud 9.264958503002427
# generación 577 tiene como mejor aptitud 9.264958503002427
# generación 578 tiene como mejor aptitud 9.264958503002427
# generación 579 tiene como mejor aptitud 9.264958503002427
# generación 580 tiene como mejor aptitud 9.264958503002427
# generación 581 tiene como mejor aptitud 9.264958503002427
# generación 582 tiene como mejor aptitud 9.264958503002427
# generación 583 tiene como mejor aptitud 9.264958503002427
# generación 584 tiene como mejor aptitud 9.264958503002427
# generación 585 tiene como mejor aptitud 9.264958503002427
# generación 586 tiene como mejor aptitud 9.264958503002427
# generación 587 tiene como mejor aptitud 9.264958503002427
# generación 588 tiene como mejor aptitud 9.264958503002427
# generación 589 tiene como mejor aptitud 9.264958503002427
# generación 590 tiene como mejor aptitud 9.264958503002427
# generación 591 tiene como mejor aptitud 9.264958503002427
# generación 592 tiene como mejor aptitud 9.264958503002427
# generación 593 tiene como mejor aptitud 9.264958503002427
# generación 594 tiene como mejor aptitud 9.264958503002427
# generación 595 tiene como mejor aptitud 9.264958503002427
# generación 596 tiene como mejor aptitud 9.264958503002427
# generación 597 tiene como mejor aptitud 9.264958503002427
# generación 598 tiene como mejor aptitud 9.264958503002427
# generación 599 tiene como mejor aptitud 9.264958503002427
# generación 600 tiene como mejor aptitud 9.264958503002427
# generación 601 tiene como mejor aptitud 9.264958503002427
# generación 602 tiene como mejor aptitud 9.264958503002427
# generación 603 tiene como mejor aptitud 9.264958503002427
# generación 604 tiene como mejor aptitud 9.264958503002427
# generación 605 tiene como mejor aptitud 9.264958503002427
# generación 606 tiene como mejor aptitud 9.264958503002427
# generación 607 tiene como mejor aptitud 9.264958503002427
# generación 608 tiene como mejor aptitud 9.264958503002427
# generación 609 tiene como mejor aptitud 9.264958503002427
# generación 610 tiene como mejor aptitud 9.264958503002427
# generación 611 tiene como mejor aptitud 9.264958503002427
# generación 612 tiene como mejor aptitud 9.264958503002427
# generación 613 tiene como mejor aptitud 9.264958503002427
# generación 614 tiene como mejor aptitud 9.264958503002427
# generación 615 tiene como mejor aptitud 9.264958503002427
# generación 616 tiene como mejor aptitud 9.264958503002427
# generación 617 tiene como mejor aptitud 9.264958503002427
# generación 618 tiene como mejor aptitud 9.264958503002427
# generación 619 tiene como mejor aptitud 9.264958503002427
# generación 620 tiene como mejor aptitud 9.264958503002427
# generación 621 tiene como mejor aptitud 9.264958503002427
# generación 622 tiene como mejor aptitud 9.264958503002427
# generación 623 tiene como mejor aptitud 9.264958503002427
# generación 624 tiene como mejor aptitud 9.264958503002427
# generación 625 tiene como mejor aptitud 9.264958503002427
# generación 626 tiene como mejor aptitud 9.264958503002427
# generación 627 tiene como mejor aptitud 9.264958503002427
# generación 628 tiene como mejor aptitud 9.264958503002427
# generación 629 tiene como mejor aptitud 9.264958503002427
# generación 630 tiene como mejor aptitud 9.264958503002427
# generación 631 tiene como mejor aptitud 9.264958503002427
# generación 632 tiene como mejor aptitud 9.264958503002427
# generación 633 tiene como mejor aptitud 9.264958503002427
# generación 634 tiene como mejor aptitud 9.264958503002427
# generación 635 tiene como mejor aptitud 9.264958503002427
# generación 636 tiene como mejor aptitud 9.264958503002427
# generación 637 tiene como mejor aptitud 9.264958503002427
# generación 638 tiene como mejor aptitud 9.264958503002427
# generación 639 tiene como mejor aptitud 9.264958503002427
# generación 640 tiene como mejor aptitud 9.264958503002427
# generación 641 tiene como mejor aptitud 9.264958503002427
# generación 642 tiene como mejor aptitud 9.264958503002427
# generación 643 tiene como mejor aptitud 9.264958503002427
# generación 644 tiene como mejor aptitud 9.264958503002427
# generación 645 tiene como mejor aptitud 9.264958503002427
# generación 646 tiene como mejor aptitud 9.264958503002427
# generación 647 tiene como mejor aptitud 9.264958503002427
# generación 648 tiene como mejor aptitud 9.264958503002427
# generación 649 tiene como mejor aptitud 9.264958503002427
# generación 650 tiene como mejor aptitud 9.264958503002427
# generación 651 tiene como mejor aptitud 9.264958503002427
# generación 652 tiene como mejor aptitud 9.264958503002427
# generación 653 tiene como mejor aptitud 9.264958503002427
# generación 654 tiene como mejor aptitud 9.264958503002427
# generación 655 tiene como mejor aptitud 9.264958503002427
# generación 656 tiene como mejor aptitud 9.264958503002427
# generación 657 tiene como mejor aptitud 9.264958503002427
# generación 658 tiene como mejor aptitud 9.264958503002427
# generación 659 tiene como mejor aptitud 5.379364492789703
# generación 660 tiene como mejor aptitud 5.379364492789703
# generación 661 tiene como mejor aptitud 5.379364492789703
# generación 662 tiene como mejor aptitud 5.379364492789703
# generación 663 tiene como mejor aptitud 5.379364492789703
# generación 664 tiene como mejor aptitud 5.379364492789703
# generación 665 tiene como mejor aptitud 5.379364492789703
# generación 666 tiene como mejor aptitud 5.379364492789703
# generación 667 tiene como mejor aptitud 5.379364492789703
# generación 668 tiene como mejor aptitud 5.379364492789703
# generación 669 tiene como mejor aptitud 5.379364492789703
# generación 670 tiene como mejor aptitud 5.379364492789703
# generación 671 tiene como mejor aptitud 5.379364492789703
# generación 672 tiene como mejor aptitud 5.379364492789703
# generación 673 tiene como mejor aptitud 5.379364492789703
# generación 674 tiene como mejor aptitud 5.379364492789703
# generación 675 tiene como mejor aptitud 5.379364492789703
# generación 676 tiene como mejor aptitud 5.379364492789703
# generación 677 tiene como mejor aptitud 5.379364492789703
# generación 678 tiene como mejor aptitud 5.379364492789703
# generación 679 tiene como mejor aptitud 5.379364492789703
# generación 680 tiene como mejor aptitud 5.379364492789703
# generación 681 tiene como mejor aptitud 5.379364492789703
# generación 682 tiene como mejor aptitud 5.379364492789703
# generación 683 tiene como mejor aptitud 5.379364492789703
# generación 684 tiene como mejor aptitud 5.379364492789703
# generación 685 tiene como mejor aptitud 5.379364492789703
# generación 686 tiene como mejor aptitud 5.379364492789703
# generación 687 tiene como mejor aptitud 5.379364492789703
# generación 688 tiene como mejor aptitud 5.379364492789703
# generación 689 tiene como mejor aptitud 5.379364492789703
# generación 690 tiene como mejor aptitud 5.379364492789703
# generación 691 tiene como mejor aptitud 5.379364492789703
# generación 692 tiene como mejor aptitud 5.379364492789703
# generación 693 tiene como mejor aptitud 5.379364492789703
# generación 694 tiene como mejor aptitud 5.379364492789703
# generación 695 tiene como mejor aptitud 5.379364492789703
# generación 696 tiene como mejor aptitud 5.379364492789703
# generación 697 tiene como mejor aptitud 5.379364492789703
# generación 698 tiene como mejor aptitud 5.379364492789703
# generación 699 tiene como mejor aptitud 5.379364492789703
# generación 700 tiene como mejor aptitud 5.379364492789703
# generación 701 tiene como mejor aptitud 5.379364492789703
# generación 702 tiene como mejor aptitud 5.379364492789703
# generación 703 tiene como mejor aptitud 5.379364492789703
# generación 704 tiene como mejor aptitud 5.379364492789703
# generación 705 tiene como mejor aptitud 5.379364492789703
# generación 706 tiene como mejor aptitud 5.379364492789703
# generación 707 tiene como mejor aptitud 5.379364492789703
# generación 708 tiene como mejor aptitud 5.379364492789703
# generación 709 tiene como mejor aptitud 5.379364492789703
# generación 710 tiene como mejor aptitud 5.379364492789703
# generación 711 tiene como mejor aptitud 5.379364492789703
# generación 712 tiene como mejor aptitud 5.379364492789703
# generación 713 tiene como mejor aptitud 5.379364492789703
# generación 714 tiene como mejor aptitud 5.379364492789703
# generación 715 tiene como mejor aptitud 5.379364492789703
# generación 716 tiene como mejor aptitud 5.379364492789703
# generación 717 tiene como mejor aptitud 5.379364492789703
# generación 718 tiene como mejor aptitud 5.379364492789703
# generación 719 tiene como mejor aptitud 5.379364492789703
# generación 720 tiene como mejor aptitud 5.379364492789703
# generación 721 tiene como mejor aptitud 5.379364492789703
# generación 722 tiene como mejor aptitud 5.379364492789703
# generación 723 tiene como mejor aptitud 5.379364492789703
# generación 724 tiene como mejor aptitud 5.379364492789703
# generación 725 tiene como mejor aptitud 5.379364492789703
# generación 726 tiene como mejor aptitud 5.379364492789703
# generación 727 tiene como mejor aptitud 5.379364492789703
# generación 728 tiene como mejor aptitud 5.379364492789703
# generación 729 tiene como mejor aptitud 5.379364492789703
# generación 730 tiene como mejor aptitud 5.379364492789703
# generación 731 tiene como mejor aptitud 5.379364492789703
# generación 732 tiene como mejor aptitud 5.379364492789703
# generación 733 tiene como mejor aptitud 5.379364492789703
# generación 734 tiene como mejor aptitud 5.379364492789703
# generación 735 tiene como mejor aptitud 5.379364492789703
# generación 736 tiene como mejor aptitud 5.379364492789703
# generación 737 tiene como mejor aptitud 5.379364492789703
# generación 738 tiene como mejor aptitud 5.379364492789703
# generación 739 tiene como mejor aptitud 5.379364492789703
# generación 740 tiene como mejor aptitud 5.379364492789703
# generación 741 tiene como mejor aptitud 5.379364492789703
# generación 742 tiene como mejor aptitud 5.379364492789703
# generación 743 tiene como mejor aptitud 5.379364492789703
# generación 744 tiene como mejor aptitud 5.379364492789703
# generación 745 tiene como mejor aptitud 5.379364492789703
# generación 746 tiene como mejor aptitud 5.379364492789703
# generación 747 tiene como mejor aptitud 5.379364492789703
# generación 748 tiene como mejor aptitud 5.379364492789703
# generación 749 tiene como mejor aptitud 5.379364492789703
# generación 750 tiene como mejor aptitud 5.379364492789703
# generación 751 tiene como mejor aptitud 5.379364492789703
# generación 752 tiene como mejor aptitud 5.379364492789703
# generación 753 tiene como mejor aptitud 5.379364492789703
# generación 754 tiene como mejor aptitud 5.379364492789703
# generación 755 tiene como mejor aptitud 5.379364492789703
# generación 756 tiene como mejor aptitud 5.379364492789703
# generación 757 tiene como mejor aptitud 5.379364492789703
# generación 758 tiene como mejor aptitud 5.379364492789703
# generación 759 tiene como mejor aptitud 5.379364492789703
# generación 760 tiene como mejor aptitud 5.379364492789703
# generación 761 tiene como mejor aptitud 5.379364492789703
# generación 762 tiene como mejor aptitud 5.379364492789703
# generación 763 tiene como mejor aptitud 5.379364492789703
# generación 764 tiene como mejor aptitud 5.379364492789703
# generación 765 tiene como mejor aptitud 5.379364492789703
# generación 766 tiene como mejor aptitud 5.379364492789703
# generación 767 tiene como mejor aptitud 5.379364492789703
# generación 768 tiene como mejor aptitud 5.379364492789703
# generación 769 tiene como mejor aptitud 5.379364492789703
# generación 770 tiene como mejor aptitud 5.379364492789703
# generación 771 tiene como mejor aptitud 5.379364492789703
# generación 772 tiene como mejor aptitud 5.379364492789703
# generación 773 tiene como mejor aptitud 5.379364492789703
# generación 774 tiene como mejor aptitud 5.379364492789703
# generación 775 tiene como mejor aptitud 5.379364492789703
# generación 776 tiene como mejor aptitud 5.379364492789703
# generación 777 tiene como mejor aptitud 5.379364492789703
# generación 778 tiene como mejor aptitud 5.379364492789703
# generación 779 tiene como mejor aptitud 5.379364492789703
# generación 780 tiene como mejor aptitud 5.379364492789703
# generación 781 tiene como mejor aptitud 5.379364492789703
# generación 782 tiene como mejor aptitud 5.379364492789703
# generación 783 tiene como mejor aptitud 5.379364492789703
# generación 784 tiene como mejor aptitud 5.379364492789703
# generación 785 tiene como mejor aptitud 5.379364492789703
# generación 786 tiene como mejor aptitud 5.379364492789703
# generación 787 tiene como mejor aptitud 5.379364492789703
# generación 788 tiene como mejor aptitud 5.379364492789703
# generación 789 tiene como mejor aptitud 5.379364492789703
# generación 790 tiene como mejor aptitud 5.379364492789703
# generación 791 tiene como mejor aptitud 5.379364492789703
# generación 792 tiene como mejor aptitud 5.379364492789703
# generación 793 tiene como mejor aptitud 5.379364492789703
# generación 794 tiene como mejor aptitud 5.379364492789703
# generación 795 tiene como mejor aptitud 5.379364492789703
# generación 796 tiene como mejor aptitud 5.379364492789703
# generación 797 tiene como mejor aptitud 5.379364492789703
# generación 798 tiene como mejor aptitud 5.379364492789703
# generación 799 tiene como mejor aptitud 5.379364492789703
# generación 800 tiene como mejor aptitud 5.379364492789703
# generación 801 tiene como mejor aptitud 5.379364492789703
# generación 802 tiene como mejor aptitud 5.379364492789703
# generación 803 tiene como mejor aptitud 5.379364492789703
# generación 804 tiene como mejor aptitud 5.379364492789703
# generación 805 tiene como mejor aptitud 5.379364492789703
# generación 806 tiene como mejor aptitud 5.379364492789703
# generación 807 tiene como mejor aptitud 5.379364492789703
# generación 808 tiene como mejor aptitud 5.379364492789703
# generación 809 tiene como mejor aptitud 5.379364492789703
# generación 810 tiene como mejor aptitud 5.379364492789703
# generación 811 tiene como mejor aptitud 5.379364492789703
# generación 812 tiene como mejor aptitud 5.379364492789703
# generación 813 tiene como mejor aptitud 5.379364492789703
# generación 814 tiene como mejor aptitud 5.379364492789703
# generación 815 tiene como mejor aptitud 5.379364492789703
# generación 816 tiene como mejor aptitud 5.379364492789703
# generación 817 tiene como mejor aptitud 5.379364492789703
# generación 818 tiene como mejor aptitud 5.379364492789703
# generación 819 tiene como mejor aptitud 5.379364492789703
# generación 820 tiene como mejor aptitud 5.379364492789703
# generación 821 tiene como mejor aptitud 5.379364492789703
# generación 822 tiene como mejor aptitud 5.379364492789703
# generación 823 tiene como mejor aptitud 5.379364492789703
# generación 824 tiene como mejor aptitud 5.379364492789703
# generación 825 tiene como mejor aptitud 5.379364492789703
# generación 826 tiene como mejor aptitud 5.379364492789703
# generación 827 tiene como mejor aptitud 5.379364492789703
# generación 828 tiene como mejor aptitud 5.379364492789703
# generación 829 tiene como mejor aptitud 5.379364492789703
# generación 830 tiene como mejor aptitud 5.379364492789703
# generación 831 tiene como mejor aptitud 5.379364492789703
# generación 832 tiene como mejor aptitud 5.379364492789703
# generación 833 tiene como mejor aptitud 5.379364492789703
# generación 834 tiene como mejor aptitud 5.379364492789703
# generación 835 tiene como mejor aptitud 5.379364492789703
# generación 836 tiene como mejor aptitud 5.379364492789703
# generación 837 tiene como mejor aptitud 5.379364492789703
# generación 838 tiene como mejor aptitud 5.379364492789703
# generación 839 tiene como mejor aptitud 5.379364492789703
# generación 840 tiene como mejor aptitud 5.379364492789703
# generación 841 tiene como mejor aptitud 5.379364492789703
# generación 842 tiene como mejor aptitud 5.379364492789703
# generación 843 tiene como mejor aptitud 5.379364492789703
# generación 844 tiene como mejor aptitud 5.379364492789703
# generación 845 tiene como mejor aptitud 5.379364492789703
# generación 846 tiene como mejor aptitud 5.379364492789703
# generación 847 tiene como mejor aptitud 5.379364492789703
# generación 848 tiene como mejor aptitud 5.379364492789703
# generación 849 tiene como mejor aptitud 5.379364492789703
# generación 850 tiene como mejor aptitud 5.379364492789703
# generación 851 tiene como mejor aptitud 5.379364492789703
# generación 852 tiene como mejor aptitud 5.379364492789703
# generación 853 tiene como mejor aptitud 5.379364492789703
# generación 854 tiene como mejor aptitud 5.379364492789703
# generación 855 tiene como mejor aptitud 5.379364492789703
# generación 856 tiene como mejor aptitud 5.379364492789703
# generación 857 tiene como mejor aptitud 5.379364492789703
# generación 858 tiene como mejor aptitud 5.379364492789703
# generación 859 tiene como mejor aptitud 5.379364492789703
# generación 860 tiene como mejor aptitud 5.379364492789703
# generación 861 tiene como mejor aptitud 5.379364492789703
# generación 862 tiene como mejor aptitud 5.379364492789703
# generación 863 tiene como mejor aptitud 5.379364492789703
# generación 864 tiene como mejor aptitud 5.379364492789703
# generación 865 tiene como mejor aptitud 5.379364492789703
# generación 866 tiene como mejor aptitud 5.379364492789703
# generación 867 tiene como mejor aptitud 5.379364492789703
# generación 868 tiene como mejor aptitud 5.379364492789703
# generación 869 tiene como mejor aptitud 5.379364492789703
# generación 870 tiene como mejor aptitud 5.379364492789703
# generación 871 tiene como mejor aptitud 5.379364492789703
# generación 872 tiene como mejor aptitud 5.379364492789703
# generación 873 tiene como mejor aptitud 5.379364492789703
# generación 874 tiene como mejor aptitud 5.379364492789703
# generación 875 tiene como mejor aptitud 5.379364492789703
# generación 876 tiene como mejor aptitud 5.379364492789703
# generación 877 tiene como mejor aptitud 5.379364492789703
# generación 878 tiene como mejor aptitud 5.379364492789703
# generación 879 tiene como mejor aptitud 5.379364492789703
# generación 880 tiene como mejor aptitud 5.379364492789703
# generación 881 tiene como mejor aptitud 5.379364492789703
# generación 882 tiene como mejor aptitud 5.379364492789703
# generación 883 tiene como mejor aptitud 5.379364492789703
# generación 884 tiene como mejor aptitud 5.379364492789703
# generación 885 tiene como mejor aptitud 5.379364492789703
# generación 886 tiene como mejor aptitud 5.379364492789703
# generación 887 tiene como mejor aptitud 5.379364492789703
# generación 888 tiene como mejor aptitud 5.379364492789703
# generación 889 tiene como mejor aptitud 5.379364492789703
# generación 890 tiene como mejor aptitud 5.379364492789703
# generación 891 tiene como mejor aptitud 5.379364492789703
# generación 892 tiene como mejor aptitud 5.379364492789703
# generación 893 tiene como mejor aptitud 5.379364492789703
# generación 894 tiene como mejor aptitud 5.379364492789703
# generación 895 tiene como mejor aptitud 5.379364492789703
# generación 896 tiene como mejor aptitud 5.379364492789703
# generación 897 tiene como mejor aptitud 5.379364492789703
# generación 898 tiene como mejor aptitud 5.379364492789703
# generación 899 tiene como mejor aptitud 5.379364492789703
# generación 900 tiene como mejor aptitud 5.379364492789703
# generación 901 tiene como mejor aptitud 5.379364492789703
# generación 902 tiene como mejor aptitud 5.379364492789703
# generación 903 tiene como mejor aptitud 5.379364492789703
# generación 904 tiene como mejor aptitud 5.379364492789703
# generación 905 tiene como mejor aptitud 5.379364492789703
# generación 906 tiene como mejor aptitud 5.379364492789703
# generación 907 tiene como mejor aptitud 5.379364492789703
# generación 908 tiene como mejor aptitud 5.379364492789703
# generación 909 tiene como mejor aptitud 5.379364492789703
# generación 910 tiene como mejor aptitud 5.379364492789703
# generación 911 tiene como mejor aptitud 5.379364492789703
# generación 912 tiene como mejor aptitud 5.379364492789703
# generación 913 tiene como mejor aptitud 5.379364492789703
# generación 914 tiene como mejor aptitud 5.379364492789703
# generación 915 tiene como mejor aptitud 5.379364492789703
# generación 916 tiene como mejor aptitud 5.379364492789703
# generación 917 tiene como mejor aptitud 5.379364492789703
# generación 918 tiene como mejor aptitud 5.379364492789703
# generación 919 tiene como mejor aptitud 5.379364492789703
# generación 920 tiene como mejor aptitud 5.379364492789703
# generación 921 tiene como mejor aptitud 5.379364492789703
# generación 922 tiene como mejor aptitud 5.379364492789703
# generación 923 tiene como mejor aptitud 5.379364492789703
# generación 924 tiene como mejor aptitud 5.379364492789703
# generación 925 tiene como mejor aptitud 5.379364492789703
# generación 926 tiene como mejor aptitud 5.379364492789703
# generación 927 tiene como mejor aptitud 5.379364492789703
# generación 928 tiene como mejor aptitud 5.379364492789703
# generación 929 tiene como mejor aptitud 5.379364492789703
# generación 930 tiene como mejor aptitud 5.379364492789703
# generación 931 tiene como mejor aptitud 5.379364492789703
# generación 932 tiene como mejor aptitud 5.379364492789703
# generación 933 tiene como mejor aptitud 5.379364492789703
# generación 934 tiene como mejor aptitud 5.379364492789703
# generación 935 tiene como mejor aptitud 5.379364492789703
# generación 936 tiene como mejor aptitud 5.379364492789703
# generación 937 tiene como mejor aptitud 5.379364492789703
# generación 938 tiene como mejor aptitud 5.379364492789703
# generación 939 tiene como mejor aptitud 5.379364492789703
# generación 940 tiene como mejor aptitud 5.379364492789703
# generación 941 tiene como mejor aptitud 5.379364492789703
# generación 942 tiene como mejor aptitud 5.379364492789703
# generación 943 tiene como mejor aptitud 5.379364492789703
# generación 944 tiene como mejor aptitud 5.379364492789703
# generación 945 tiene como mejor aptitud 5.379364492789703
# generación 946 tiene como mejor aptitud 5.379364492789703
# generación 947 tiene como mejor aptitud 5.379364492789703
# generación 948 tiene como mejor aptitud 5.379364492789703
# generación 949 tiene como mejor aptitud 5.379364492789703
# generación 950 tiene como mejor aptitud 5.379364492789703
# generación 951 tiene como mejor aptitud 5.379364492789703
# generación 952 tiene como mejor aptitud 5.379364492789703
# generación 953 tiene como mejor aptitud 5.379364492789703
# generación 954 tiene como mejor aptitud 5.379364492789703
# generación 955 tiene como mejor aptitud 5.379364492789703
# generación 956 tiene como mejor aptitud 5.379364492789703
# generación 957 tiene como mejor aptitud 5.379364492789703
# generación 958 tiene como mejor aptitud 5.379364492789703
# generación 959 tiene como mejor aptitud 5.379364492789703
# generación 960 tiene como mejor aptitud 5.379364492789703
# generación 961 tiene como mejor aptitud 5.379364492789703
# generación 962 tiene como mejor aptitud 5.379364492789703
# generación 963 tiene como mejor aptitud 5.379364492789703
# generación 964 tiene como mejor aptitud 5.379364492789703
# generación 965 tiene como mejor aptitud 5.379364492789703
# generación 966 tiene como mejor aptitud 5.379364492789703
# generación 967 tiene como mejor aptitud 5.379364492789703
# generación 968 tiene como mejor aptitud 5.379364492789703
# generación 969 tiene como mejor aptitud 5.379364492789703
# generación 970 tiene como mejor aptitud 5.379364492789703
# generación 971 tiene como mejor aptitud 5.379364492789703
# generación 972 tiene como mejor aptitud 5.379364492789703
# generación 973 tiene como mejor aptitud 5.379364492789703
# generación 974 tiene como mejor aptitud 5.379364492789703
# generación 975 tiene como mejor aptitud 5.379364492789703
# generación 976 tiene como mejor aptitud 5.379364492789703
# generación 977 tiene como mejor aptitud 5.379364492789703
# generación 978 tiene como mejor aptitud 5.379364492789703
# generación 979 tiene como mejor aptitud 5.379364492789703
# generación 980 tiene como mejor aptitud 5.379364492789703
# generación 981 tiene como mejor aptitud 5.379364492789703
# generación 982 tiene como mejor aptitud 5.379364492789703
# generación 983 tiene como mejor aptitud 5.379364492789703
# generación 984 tiene como mejor aptitud 5.379364492789703
# generación 985 tiene como mejor aptitud 5.379364492789703
# generación 986 tiene como mejor aptitud 5.379364492789703
# generación 987 tiene como mejor aptitud 5.379364492789703
# generación 988 tiene como mejor aptitud 5.379364492789703
# generación 989 tiene como mejor aptitud 5.379364492789703
# generación 990 tiene como mejor aptitud 5.379364492789703
# generación 991 tiene como mejor aptitud 5.379364492789703
# generación 992 tiene como mejor aptitud 5.379364492789703
# generación 993 tiene como mejor aptitud 5.379364492789703
# generación 994 tiene como mejor aptitud 5.379364492789703
# generación 995 tiene como mejor aptitud 5.379364492789703
# generación 996 tiene como mejor aptitud 5.379364492789703
# generación 997 tiene como mejor aptitud 5.379364492789703
# generación 998 tiene como mejor aptitud 5.379364492789703
# generación 999 tiene como mejor aptitud 5.379364492789703
# generación 1000 tiene como mejor aptitud 5.379364492789703

# %%
print(aptitud(inpob[0]))
# Out:
# 5.379364492789703

# %%
plt.figure(figsize=(10, 5))  # Crea una figura con un tamaño específico
plt.plot(resultados,  linestyle='-', color='b')
plt.title('Gráfico de convergencia')  
plt.xlabel('generación')  
plt.ylabel('mejor aptitud')  
plt.grid(True)

plt.show()

# %%
x = np.array([arr[0] for arr in inpob])
y = np.array([arr[1] for arr in inpob])
z = np.array([arr[2] for arr in inpob])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


scatter = ax.scatter(x, y, z, alpha = 0.5)
plt.show()

# %%
# %matplotlib notebook
# from mpl_toolkits.mplot3d import Axes3D


# def funcion(x, y):
#     return -x**2 - y**2


# x = np.linspace(-10, 10, 400)
# y = np.linspace(-10, 10, 400)
# X, Y = np.meshgrid(x, y)
# Z = funcion(X, Y)


# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z, cmap='viridis')


# ax.set_xlim([-10, 10])
# ax.set_ylim([-10, 10])
# ax.set_zlim([np.min(Z), np.max(Z)])


# ax.set_box_aspect([1,1,1])  


# plt.show()
